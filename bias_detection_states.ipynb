# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from model.preprocess import ACSIncomePreprocess
from model.model import ACSIncomeModel
from utils.constants import states

# %%
preprocess = ACSIncomePreprocess()
model = ACSIncomeModel()

# %% [markdown]
# ## Bias Metrics Calculation for each State

# %%
train, test = preprocess.get_preprocessed_data()

# %%
for state in states:
  model.print_model_metrics_for_state(train, test, state)
# Out:
# -----------------------------------
#   RESULTS for state: AL
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        7849
#               1        4120
# 1             0        2977
#               1         681
# dtype: int64
# Eğitim örnek sayısı: 15627
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83    315441
#            1       0.76      0.55      0.64    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.77      0.72      0.73    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 1.910628230622701
# Equal opportunity diff: 0.18316108652757646
# Statistical parity: 0.14155160761813923
# EO: 0.12210358735561173
# -----------------------------------
#   RESULTS for state: AK
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        743
#               1        728
# 1             0        759
#               1        239
# dtype: int64
# Eğitim örnek sayısı: 2469
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81    315441
#            1       0.66      0.73      0.69    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.75      0.75      0.75    499350
# weighted avg       0.77      0.76      0.76    499350
#
# Disparate impact: 2.091157912476685
# Equal opportunity diff: 0.2606202428732115
# Statistical parity: 0.23862934086138843
# EO: 0.20998140504671542
# -----------------------------------
#   RESULTS for state: AZ
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11549
#               1         6807
# 1             0         3821
#               1         1116
# dtype: int64
# Eğitim örnek sayısı: 23293
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83    315441
#            1       0.73      0.61      0.66    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.74      0.75    499350
# weighted avg       0.77      0.77      0.77    499350
#
# Disparate impact: 1.8607941843783151
# Equal opportunity diff: 0.184476325303278
# Statistical parity: 0.15756076536733765
# EO: 0.13217088521078568
# -----------------------------------
#   RESULTS for state: AR
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        5827
#               1        2369
# 1             0        1315
#               1         281
# dtype: int64
# Eğitim örnek sayısı: 9792
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83    315441
#            1       0.78      0.50      0.61    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.77      0.71      0.72    499350
# weighted avg       0.77      0.76      0.75    499350
#
# Disparate impact: 1.910567629534802
# Equal opportunity diff: 0.16910848469312678
# Statistical parity: 0.12493306798834583
# EO: 0.10826434379237151
# -----------------------------------
#   RESULTS for state: CA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        47067
#               1        37702
# 1             0        33641
#               1        18633
# dtype: int64
# Eğitim örnek sayısı: 137043
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.80    315441
#            1       0.65      0.78      0.71    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.75      0.77      0.76    499350
# weighted avg       0.78      0.77      0.77    499350
#
# Disparate impact: 1.5098848620475498
# Equal opportunity diff: 0.12553943411603896
# Statistical parity: 0.16067967973540742
# EO: 0.11399692755435022
# -----------------------------------
#   RESULTS for state: CO
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11053
#               1         8332
# 1             0         1813
#               1          837
# dtype: int64
# Eğitim örnek sayısı: 22035
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83    315441
#            1       0.73      0.67      0.70    183909
#
#     accuracy                           0.79    499350
#    macro avg       0.77      0.76      0.77    499350
# weighted avg       0.78      0.79      0.78    499350
#
# Disparate impact: 1.3504508649756914
# Equal opportunity diff: 0.05422956661984191
# Statistical parity: 0.09309439220792198
# EO: 0.04613298396099554
# -----------------------------------
#   RESULTS for state: CT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        5618
#               1        5827
# 1             0        1693
#               1         841
# dtype: int64
# Eğitim örnek sayısı: 13979
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80    315441
#            1       0.65      0.78      0.71    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.75      0.77      0.76    499350
# weighted avg       0.78      0.77      0.77    499350
#
# Disparate impact: 1.5279907306004066
# Equal opportunity diff: 0.1289715898102124
# Statistical parity: 0.16573659117667178
# EO: 0.11867460485930227
# -----------------------------------
#   RESULTS for state: DE
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1464
#               1        1075
# 1             0         558
#               1         236
# dtype: int64
# Eğitim örnek sayısı: 3333
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82    315441
#            1       0.69      0.72      0.70    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.76      0.76      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.576037851112344
# Equal opportunity diff: 0.1283062354302602
# Statistical parity: 0.1525111409640459
# EO: 0.1095547971267019
# -----------------------------------
#   RESULTS for state: FL
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        35445
#               1        19944
# 1             0        10784
#               1         3082
# dtype: int64
# Eğitim örnek sayısı: 69255
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83    315441
#            1       0.74      0.56      0.64    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.73      0.74    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 2.259402736830827
# Equal opportunity diff: 0.25051190227239356
# Statistical parity: 0.17719628916981525
# EO: 0.16634877779738538
# -----------------------------------
#   RESULTS for state: GA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        14536
#               1         9497
# 1             0         8493
#               1         3116
# dtype: int64
# Eğitim örnek sayısı: 35642
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83    315441
#            1       0.73      0.64      0.68    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.75      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.7435235756074732
# Equal opportunity diff: 0.16205931791903416
# Statistical parity: 0.15036141119952343
# EO: 0.11910779390217208
# -----------------------------------
#   RESULTS for state: HI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0         765
#               1         683
# 1             0        2538
#               1        1438
# dtype: int64
# Eğitim örnek sayısı: 5424
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81    315441
#            1       0.67      0.74      0.70    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.75      0.76      0.76    499350
# weighted avg       0.78      0.77      0.77    499350
#
# Disparate impact: 1.525088132179335
# Equal opportunity diff: 0.13416974551753635
# Statistical parity: 0.15089365690173456
# EO: 0.11012712886092185
# -----------------------------------
#   RESULTS for state: ID
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3711
#               1        1603
# 1             0         399
#               1          77
# dtype: int64
# Eğitim örnek sayısı: 5790
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83    315441
#            1       0.78      0.46      0.58    183909
#
#     accuracy                           0.75    499350
#    macro avg       0.76      0.69      0.70    499350
# weighted avg       0.76      0.75      0.73    499350
#
# Disparate impact: 4.663410138163673
# Equal opportunity diff: 0.36586461551638594
# Statistical parity: 0.20676830199290896
# EO: 0.22420769618315636
# -----------------------------------
#   RESULTS for state: IL
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        22192
#               1        15644
# 1             0         6293
#               1         2707
# dtype: int64
# Eğitim örnek sayısı: 46836
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82    315441
#            1       0.70      0.69      0.70    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.76      0.76      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.615124766500021
# Equal opportunity diff: 0.14511764354411272
# Statistical parity: 0.15209313419959833
# EO: 0.11445604479582293
# -----------------------------------
#   RESULTS for state: IN
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        14796
#               1         7020
# 1             0         2175
#               1          585
# dtype: int64
# Eğitim örnek sayısı: 24576
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83    315441
#            1       0.75      0.55      0.64    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.72      0.73    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 1.8142788696646974
# Equal opportunity diff: 0.16769741843711794
# Statistical parity: 0.1334970873646126
# EO: 0.11221966690193463
# -----------------------------------
#   RESULTS for state: IA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        7971
#               1        3692
# 1             0         565
#               1         103
# dtype: int64
# Eğitim örnek sayısı: 12331
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84    315441
#            1       0.78      0.55      0.65    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.78      0.73      0.74    499350
# weighted avg       0.78      0.78      0.77    499350
#
# Disparate impact: 2.2887258959030845
# Equal opportunity diff: 0.23926810550496652
# Statistical parity: 0.16926360000256227
# EO: 0.15675652965699255
# -----------------------------------
#   RESULTS for state: KS
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6650
#               1        3193
# 1             0         993
#               1         298
# dtype: int64
# Eğitim örnek sayısı: 11134
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83    315441
#            1       0.77      0.54      0.64    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.77      0.72      0.74    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 1.4968737045668723
# Equal opportunity diff: 0.087056464517971
# Statistical parity: 0.09210610987210713
# EO: 0.0596665609231955
# -----------------------------------
#   RESULTS for state: KY
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        9379
#               1        4475
# 1             0        1245
#               1         281
# dtype: int64
# Eğitim örnek sayısı: 15380
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83    315441
#            1       0.76      0.53      0.62    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.72      0.73    499350
# weighted avg       0.76      0.76      0.75    499350
#
# Disparate impact: 3.860133909793278
# Equal opportunity diff: 0.37810458662497304
# Statistical parity: 0.2288034235630051
# EO: 0.24029829576630335
# -----------------------------------
#   RESULTS for state: LA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6305
#               1        4010
# 1             0        3359
#               1         857
# dtype: int64
# Eğitim örnek sayısı: 14531
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83    315441
#            1       0.73      0.59      0.65    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.73      0.74    499350
# weighted avg       0.76      0.77      0.76    499350
#
# Disparate impact: 2.5288960164158025
# Equal opportunity diff: 0.3002711809338159
# Statistical parity: 0.20840611965342376
# EO: 0.2019085003916655
# -----------------------------------
#   RESULTS for state: ME
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3197
#               1        1499
# 1             0         201
#               1          37
# dtype: int64
# Eğitim örnek sayısı: 4934
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83    315441
#            1       0.76      0.52      0.62    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.71      0.72    499350
# weighted avg       0.76      0.76      0.75    499350
#
# Disparate impact: 4.796018247661515
# Equal opportunity diff: 0.4152169956610025
# Statistical parity: 0.24258500461317878
# EO: 0.2611176045041272
# -----------------------------------
#   RESULTS for state: MD
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6870
#               1        7850
# 1             0        4988
#               1        3430
# dtype: int64
# Eğitim örnek sayısı: 23138
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.81    315441
#            1       0.66      0.77      0.71    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.75      0.77      0.76    499350
# weighted avg       0.78      0.77      0.77    499350
#
# Disparate impact: 1.5364614375335217
# Equal opportunity diff: 0.13509496932092746
# Statistical parity: 0.16381053561952363
# EO: 0.11910038330670288
# -----------------------------------
#   RESULTS for state: MA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11757
#               1        11282
# 1             0         3175
#               1         1753
# dtype: int64
# Eğitim örnek sayısı: 27967
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.80    315441
#            1       0.65      0.78      0.71    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.77      0.76    499350
# weighted avg       0.78      0.77      0.77    499350
#
# Disparate impact: 1.5121518359299486
# Equal opportunity diff: 0.1212205049315358
# Statistical parity: 0.1616364731494278
# EO: 0.11330765227637253
# -----------------------------------
#   RESULTS for state: MI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        19652
#               1        10632
# 1             0         3490
#               1         1259
# dtype: int64
# Eğitim örnek sayısı: 35033
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83    315441
#            1       0.74      0.61      0.67    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.74      0.75    499350
# weighted avg       0.77      0.78      0.77    499350
#
# Disparate impact: 1.7310202887889834
# Equal opportunity diff: 0.15680643846224318
# Statistical parity: 0.14163825830967805
# EO: 0.11231323912506996
# -----------------------------------
#   RESULTS for state: MN
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        12061
#               1         7718
# 1             0         1504
#               1          399
# dtype: int64
# Eğitim örnek sayısı: 21682
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83    315441
#            1       0.73      0.65      0.69    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.75      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 2.042693274903525
# Equal opportunity diff: 0.2251300911976929
# Statistical parity: 0.18736324825829093
# EO: 0.16271742865381061
# -----------------------------------
#   RESULTS for state: MS
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        4019
#               1        1981
# 1             0        2625
#               1         515
# dtype: int64
# Eğitim örnek sayısı: 9140
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.83    315441
#            1       0.77      0.49      0.60    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.70      0.71    499350
# weighted avg       0.76      0.76      0.74    499350
#
# Disparate impact: 2.3299269459296426
# Equal opportunity diff: 0.22806203232225236
# Statistical parity: 0.15251078215068875
# EO: 0.14559411879118345
# -----------------------------------
#   RESULTS for state: MO
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        13434
#               1         6247
# 1             0         1929
#               1          603
# dtype: int64
# Eğitim örnek sayısı: 22213
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83    315441
#            1       0.76      0.55      0.64    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.77      0.73      0.74    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 1.8541954783384218
# Equal opportunity diff: 0.16736044767795327
# Statistical parity: 0.1359205336711293
# EO: 0.1133705197547045
# -----------------------------------
#   RESULTS for state: MT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        2373
#               1        1043
# 1             0         244
#               1          65
# dtype: int64
# Eğitim örnek sayısı: 3725
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83    315441
#            1       0.78      0.48      0.60    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.70      0.71    499350
# weighted avg       0.76      0.76      0.74    499350
#
# Disparate impact: 1.9559333742177278
# Equal opportunity diff: 0.17849325305789976
# Statistical parity: 0.12526689593334267
# EO: 0.11213378646583302
# -----------------------------------
#   RESULTS for state: NE
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        4664
#               1        2212
# 1             0         520
#               1         126
# dtype: int64
# Eğitim örnek sayısı: 7522
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83    315441
#            1       0.77      0.49      0.60    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.70      0.71    499350
# weighted avg       0.76      0.76      0.74    499350
#
# Disparate impact: 2.9514760471679513
# Equal opportunity diff: 0.2921097764728168
# Statistical parity: 0.18064288678661333
# EO: 0.18353413481279401
# -----------------------------------
#   RESULTS for state: NV
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        4283
#               1        2721
# 1             0        2582
#               1         763
# dtype: int64
# Eğitim örnek sayısı: 10349
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82    315441
#            1       0.70      0.66      0.68    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.75      0.75    499350
# weighted avg       0.77      0.77      0.77    499350
#
# Disparate impact: 1.8868242486799114
# Equal opportunity diff: 0.209668126990592
# Statistical parity: 0.18198841780657604
# EO: 0.15539647131749637
# -----------------------------------
#   RESULTS for state: NH
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3154
#               1        2111
# 1             0         226
#               1          93
# dtype: int64
# Eğitim örnek sayısı: 5584
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83    315441
#            1       0.71      0.66      0.68    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.76      0.75      0.75    499350
# weighted avg       0.77      0.78      0.77    499350
#
# Disparate impact: 2.8608175210475943
# Equal opportunity diff: 0.34937346893379956
# Statistical parity: 0.2575802601359093
# EO: 0.24864182053558537
# -----------------------------------
#   RESULTS for state: NJ
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11689
#               1        12702
# 1             0         5346
#               1         3586
# dtype: int64
# Eğitim örnek sayısı: 33323
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80    315441
#            1       0.64      0.81      0.72    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.77      0.76    499350
# weighted avg       0.79      0.76      0.77    499350
#
# Disparate impact: 1.52661723535325
# Equal opportunity diff: 0.11936904416068206
# Statistical parity: 0.17391416043472924
# EO: 0.12134589071906428
# -----------------------------------
#   RESULTS for state: NM
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        2962
#               1        1502
# 1             0        1331
#               1         317
# dtype: int64
# Eğitim örnek sayısı: 6112
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83    315441
#            1       0.76      0.52      0.62    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.71      0.72    499350
# weighted avg       0.76      0.76      0.75    499350
#
# Disparate impact: 2.249036979857537
# Equal opportunity diff: 0.2316553746045933
# Statistical parity: 0.16012857354680618
# EO: 0.1507256501028338
# -----------------------------------
#   RESULTS for state: NY
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        28559
#               1        23129
# 1             0        13697
#               1         6768
# dtype: int64
# Eğitim örnek sayısı: 72153
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82    315441
#            1       0.68      0.71      0.70    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.75      0.76      0.76    499350
# weighted avg       0.77      0.77      0.77    499350
#
# Disparate impact: 1.4760085784576797
# Equal opportunity diff: 0.10173770294624152
# Statistical parity: 0.13349695373853626
# EO: 0.08913694512076148
# -----------------------------------
#   RESULTS for state: NC
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        17400
#               1         9956
# 1             0         7317
#               1         1891
# dtype: int64
# Eğitim örnek sayısı: 36564
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83    315441
#            1       0.76      0.54      0.63    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.72      0.73    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 1.9920523501352745
# Equal opportunity diff: 0.1930394016475268
# Statistical parity: 0.14697573501494424
# EO: 0.12921986218183437
# -----------------------------------
#   RESULTS for state: ND
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1768
#               1        1092
# 1             0         211
#               1          58
# dtype: int64
# Eğitim örnek sayısı: 3129
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82    315441
#            1       0.73      0.54      0.62    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.75      0.71      0.72    499350
# weighted avg       0.76      0.76      0.75    499350
#
# Disparate impact: 3.4501193192526554
# Equal opportunity diff: 0.3532409895361196
# Statistical parity: 0.2289418467173444
# EO: 0.23398408000329185
# -----------------------------------
#   RESULTS for state: OH
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        24304
#               1        13562
# 1             0         4329
#               1         1237
# dtype: int64
# Eğitim örnek sayısı: 43432
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83    315441
#            1       0.74      0.62      0.67    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.74      0.75    499350
# weighted avg       0.77      0.78      0.77    499350
#
# Disparate impact: 2.147609038129389
# Equal opportunity diff: 0.24183859461831458
# Statistical parity: 0.18653634612086203
# EO: 0.16835270706103256
# -----------------------------------
#   RESULTS for state: OK
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6448
#               1        2908
# 1             0        2527
#               1         652
# dtype: int64
# Eğitim örnek sayısı: 12535
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83    315441
#            1       0.76      0.51      0.61    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.71      0.72    499350
# weighted avg       0.76      0.76      0.75    499350
#
# Disparate impact: 1.9689630694137585
# Equal opportunity diff: 0.18360004354428594
# Statistical parity: 0.13497361162059382
# EO: 0.11983866531747338
# -----------------------------------
#   RESULTS for state: OR
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        8240
#               1        4980
# 1             0        1499
#               1         568
# dtype: int64
# Eğitim örnek sayısı: 15287
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83    315441
#            1       0.72      0.65      0.68    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.76      0.75      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.8138446528705594
# Equal opportunity diff: 0.18031022328496493
# Statistical parity: 0.16477491178756598
# EO: 0.13439118090259244
# -----------------------------------
#   RESULTS for state: PA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        26679
#               1        15717
# 1             0         4067
#               1         1429
# dtype: int64
# Eğitim örnek sayısı: 47892
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83    315441
#            1       0.71      0.68      0.70    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.76      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.467158322768383
# Equal opportunity diff: 0.0982372110540618
# Statistical parity: 0.12008281172794044
# EO: 0.07798454181238125
# -----------------------------------
#   RESULTS for state: RI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1906
#               1        1526
# 1             0         423
#               1         140
# dtype: int64
# Eğitim örnek sayısı: 3995
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81    315441
#            1       0.67      0.73      0.70    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.75      0.76      0.75    499350
# weighted avg       0.77      0.77      0.77    499350
#
# Disparate impact: 2.217465891973692
# Equal opportunity diff: 0.2919520179064621
# Statistical parity: 0.2509043992324135
# EO: 0.22692011997583605
# -----------------------------------
#   RESULTS for state: SC
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        8232
#               1        4633
# 1             0        3733
#               1         722
# dtype: int64
# Eğitim örnek sayısı: 17320
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83    315441
#            1       0.76      0.56      0.65    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.77      0.73      0.74    499350
# weighted avg       0.77      0.77      0.76    499350
#
# Disparate impact: 2.7151789593259217
# Equal opportunity diff: 0.301175679066682
# Statistical parity: 0.20152954677460105
# EO: 0.19754675373302522
# -----------------------------------
#   RESULTS for state: SD
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        2178
#               1         910
# 1             0         307
#               1          43
# dtype: int64
# Eğitim örnek sayısı: 3438
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82    315441
#            1       0.79      0.41      0.54    183909
#
#     accuracy                           0.74    499350
#    macro avg       0.76      0.67      0.68    499350
# weighted avg       0.75      0.74      0.72    499350
#
# Disparate impact: 8.738118861918373
# Equal opportunity diff: 0.3986820994998833
# Statistical parity: 0.2083388454440368
# EO: 0.23696912382229712
# -----------------------------------
#   RESULTS for state: TN
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        13365
#               1         6544
# 1             0         3043
#               1          829
# dtype: int64
# Eğitim örnek sayısı: 23781
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83    315441
#            1       0.76      0.57      0.65    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.77      0.73      0.74    499350
# weighted avg       0.77      0.77      0.77    499350
#
# Disparate impact: 1.5190885332897324
# Equal opportunity diff: 0.09696510356492549
# Statistical parity: 0.10126540088834426
# EO: 0.0681277719618913
# -----------------------------------
#   RESULTS for state: TX
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        45570
#               1        28422
# 1             0        14786
#               1         6208
# dtype: int64
# Eğitim örnek sayısı: 94986
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83    315441
#            1       0.72      0.66      0.69    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.75      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.5345636569401861
# Equal opportunity diff: 0.11545151515468577
# Statistical parity: 0.12614059678312056
# EO: 0.08809857860975134
# -----------------------------------
#   RESULTS for state: UT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6755
#               1        3538
# 1             0         952
#               1         265
# dtype: int64
# Eğitim örnek sayısı: 11510
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83    315441
#            1       0.73      0.61      0.66    183909
#
#     accuracy                           0.77    499350
#    macro avg       0.76      0.74      0.75    499350
# weighted avg       0.77      0.77      0.77    499350
#
# Disparate impact: 1.8931579459217085
# Equal opportunity diff: 0.2008464697744634
# Statistical parity: 0.15980199281836985
# EO: 0.13812939473412697
# -----------------------------------
#   RESULTS for state: VT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1612
#               1         898
# 1             0          77
#               1          25
# dtype: int64
# Eğitim örnek sayısı: 2612
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82    315441
#            1       0.73      0.57      0.64    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.75      0.72      0.73    499350
# weighted avg       0.76      0.76      0.76    499350
#
# Disparate impact: 2.0153585565629757
# Equal opportunity diff: 0.2101179120960167
# Statistical parity: 0.16328395479360908
# EO: 0.14538034056232166
# -----------------------------------
#   RESULTS for state: VA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        12659
#               1        11146
# 1             0         5575
#               1         2941
# dtype: int64
# Eğitim örnek sayısı: 32321
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83    315441
#            1       0.71      0.68      0.70    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.76      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.6416731271065326
# Equal opportunity diff: 0.13610573060587594
# Statistical parity: 0.15099462395177024
# EO: 0.11073571225679436
# -----------------------------------
#   RESULTS for state: WA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        12149
#               1         9796
# 1             0         3853
#               1         2133
# dtype: int64
# Eğitim örnek sayısı: 27931
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82    315441
#            1       0.68      0.74      0.71    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.76      0.77      0.76    499350
# weighted avg       0.78      0.78      0.78    499350
#
# Disparate impact: 1.5305740587832353
# Equal opportunity diff: 0.13046149463460655
# Statistical parity: 0.15061086388211786
# EO: 0.10805886821750392
# -----------------------------------
#   RESULTS for state: WV
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3816
#               1        1597
# 1             0         231
#               1          71
# dtype: int64
# Eğitim örnek sayısı: 5715
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83    315441
#            1       0.76      0.51      0.61    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.76      0.71      0.72    499350
# weighted avg       0.76      0.76      0.75    499350
#
# Disparate impact: 2.254082884487728
# Equal opportunity diff: 0.22648536857253937
# Statistical parity: 0.15569594364419026
# EO: 0.14670420606800633
# -----------------------------------
#   RESULTS for state: WI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        13808
#               1         7467
# 1             0         1303
#               1          346
# dtype: int64
# Eğitim örnek sayısı: 22924
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83    315441
#            1       0.75      0.60      0.66    183909
#
#     accuracy                           0.78    499350
#    macro avg       0.77      0.74      0.75    499350
# weighted avg       0.77      0.78      0.77    499350
#
# Disparate impact: 2.0973878951684037
# Equal opportunity diff: 0.22172630286993894
# Statistical parity: 0.17374858861207637
# EO: 0.1538728948138497
# -----------------------------------
#   RESULTS for state: WY
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1236
#               1         723
# 1             0         147
#               1          37
# dtype: int64
# Eğitim örnek sayısı: 2143
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82    315441
#            1       0.72      0.59      0.65    183909
#
#     accuracy                           0.76    499350
#    macro avg       0.75      0.73      0.73    499350
# weighted avg       0.76      0.76      0.76    499350
#
# Disparate impact: 1.495476930176014
# Equal opportunity diff: 0.10656949877083821
# Statistical parity: 0.10759100288723689
# EO: 0.07588720073094024
# -----------------------------------
#   RESULTS for state: PR
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3646
#               1         512
# 1             0        1968
#               1         164
# dtype: int64
# Eğitim örnek sayısı: 6290
# Test örnek sayısı: 499350
#               precision    recall  f1-score   support
#
#            0       0.68      0.98      0.80    315441
#            1       0.87      0.21      0.33    183909
#
#     accuracy                           0.70    499350
#    macro avg       0.77      0.59      0.57    499350
# weighted avg       0.75      0.70      0.63    499350
#
# Disparate impact: 1.9985643551016516
# Equal opportunity diff: 0.07976727606547349
# Statistical parity: 0.04914384311829529
# EO: 0.044553949108385775
