# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from model.preprocess import ACSIncomePreprocess
from model.model import ACSIncomeModel
from utils.constants import states

# %%
preprocess = ACSIncomePreprocess()
model = ACSIncomeModel()

# %% [markdown]
# ## Bias Metrics Calculation for each State

# %%
train, test = preprocess.get_preprocessed_data()

# %%
for state in states:
  model.print_model_metrics_for_state(train, test, state)
# Out:
# -----------------------------------
#   RESULTS for state: AL
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        7849
#               1        4120
# 1             0        2977
#               1         681
# dtype: int64
# Eğitim örnek sayısı: 15627
# Test örnek sayısı: 6641
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      4518
#            1       0.73      0.58      0.64      2123
#
#     accuracy                           0.80      6641
#    macro avg       0.77      0.74      0.75      6641
# weighted avg       0.79      0.80      0.79      6641
#
# Disparate impact: 2.5033862957368327
# Equal opportunity diff: 0.0008635578583765112
# Statistical parity: 0.18015030429449885
# EO: 0.03342816000081859
# -----------------------------------
#   RESULTS for state: AK
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        743
#               1        728
# 1             0        759
#               1        239
# dtype: int64
# Eğitim örnek sayısı: 2469
# Test örnek sayısı: 1077
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       673
#            1       0.69      0.66      0.67       404
#
#     accuracy                           0.76      1077
#    macro avg       0.74      0.74      0.74      1077
# weighted avg       0.76      0.76      0.76      1077
#
# Disparate impact: 3.095996732026144
# Equal opportunity diff: 0.0030211480362537764
# Statistical parity: 0.33223258223258223
# EO: 0.01579628830384118
# -----------------------------------
#   RESULTS for state: AZ
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11549
#               1         6807
# 1             0         3821
#               1         1116
# dtype: int64
# Eğitim örnek sayısı: 23293
# Test örnek sayısı: 9984
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      6607
#            1       0.70      0.63      0.66      3377
#
#     accuracy                           0.79      9984
#    macro avg       0.76      0.75      0.75      9984
# weighted avg       0.78      0.79      0.78      9984
#
# Disparate impact: 2.2705524796795857
# Equal opportunity diff: 0.0035542198972303663
# Statistical parity: 0.19223908561260022
# EO: 0.028652273655462076
# -----------------------------------
#   RESULTS for state: AR
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        5827
#               1        2369
# 1             0        1315
#               1         281
# dtype: int64
# Eğitim örnek sayısı: 9792
# Test örnek sayısı: 4137
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      3054
#            1       0.68      0.54      0.60      1083
#
#     accuracy                           0.81      4137
#    macro avg       0.76      0.72      0.74      4137
# weighted avg       0.80      0.81      0.80      4137
#
# Disparate impact: 2.6591663363783526
# Equal opportunity diff: 0.0007613247049866769
# Statistical parity: 0.1437629922146016
# EO: 0.020603987414528062
# -----------------------------------
#   RESULTS for state: CA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        47067
#               1        37702
# 1             0        33641
#               1        18633
# dtype: int64
# Eğitim örnek sayısı: 137043
# Test örnek sayısı: 58622
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82     34622
#            1       0.75      0.73      0.74     24000
#
#     accuracy                           0.79     58622
#    macro avg       0.78      0.78      0.78     58622
# weighted avg       0.79      0.79      0.79     58622
#
# Disparate impact: 1.3704278891640578
# Equal opportunity diff: 0.015984479728728598
# Statistical parity: 0.12066831216369484
# EO: 0.032764331252257514
# -----------------------------------
#   RESULTS for state: CO
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11053
#               1         8332
# 1             0         1813
#               1          837
# dtype: int64
# Eğitim örnek sayısı: 22035
# Test örnek sayısı: 9271
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      5468
#            1       0.74      0.72      0.73      3803
#
#     accuracy                           0.78      9271
#    macro avg       0.78      0.77      0.77      9271
# weighted avg       0.78      0.78      0.78      9271
#
# Disparate impact: 1.3886758271115311
# Equal opportunity diff: 0.0009434695906725104
# Statistical parity: 0.11401643288276408
# EO: 0.005140765528196768
# -----------------------------------
#   RESULTS for state: CT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        5618
#               1        5827
# 1             0        1693
#               1         841
# dtype: int64
# Eğitim örnek sayısı: 13979
# Test örnek sayısı: 5806
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79      3011
#            1       0.77      0.79      0.78      2795
#
#     accuracy                           0.79      5806
#    macro avg       0.79      0.79      0.79      5806
# weighted avg       0.79      0.79      0.79      5806
#
# Disparate impact: 1.882901994060246
# Equal opportunity diff: 0.0038454379015973182
# Statistical parity: 0.2522577125886417
# EO: 0.006317422163686422
# -----------------------------------
#   RESULTS for state: DE
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1464
#               1        1075
# 1             0         558
#               1         236
# dtype: int64
# Eğitim örnek sayısı: 3333
# Test örnek sayısı: 1380
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       853
#            1       0.71      0.69      0.70       527
#
#     accuracy                           0.77      1380
#    macro avg       0.76      0.76      0.76      1380
# weighted avg       0.77      0.77      0.77      1380
#
# Disparate impact: 1.4588235294117649
# Equal opportunity diff: 0.0
# Statistical parity: 0.12580645161290327
# EO: 0.005813953488372103
# -----------------------------------
#   RESULTS for state: FL
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        35445
#               1        19944
# 1             0        10784
#               1         3082
# dtype: int64
# Eğitim örnek sayısı: 69255
# Test örnek sayısı: 29670
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.84     19920
#            1       0.70      0.59      0.64      9750
#
#     accuracy                           0.78     29670
#    macro avg       0.76      0.74      0.74     29670
# weighted avg       0.78      0.78      0.78     29670
#
# Disparate impact: 2.523149390457869
# Equal opportunity diff: 0.006854335471840236
# Statistical parity: 0.19078462590950715
# EO: 0.07346315143194626
# -----------------------------------
#   RESULTS for state: GA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        14536
#               1         9497
# 1             0         8493
#               1         3116
# dtype: int64
# Eğitim örnek sayısı: 35642
# Test örnek sayısı: 15273
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85      9841
#            1       0.73      0.68      0.70      5432
#
#     accuracy                           0.80     15273
#    macro avg       0.78      0.77      0.78     15273
# weighted avg       0.79      0.80      0.80     15273
#
# Disparate impact: 1.831938973615532
# Equal opportunity diff: 0.004804333024969696
# Statistical parity: 0.17562206082284715
# EO: 0.024629167324894317
# -----------------------------------
#   RESULTS for state: HI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0         765
#               1         683
# 1             0        2538
#               1        1438
# dtype: int64
# Eğitim örnek sayısı: 5424
# Test örnek sayısı: 2307
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83      1481
#            1       0.69      0.67      0.68       826
#
#     accuracy                           0.78      2307
#    macro avg       0.76      0.75      0.75      2307
# weighted avg       0.77      0.78      0.77      2307
#
# Disparate impact: 1.5655580712469161
# Equal opportunity diff: -0.0008496176720475786
# Statistical parity: 0.1701708855324549
# EO: 0.0018461354074904971
# -----------------------------------
#   RESULTS for state: ID
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3711
#               1        1603
# 1             0         399
#               1          77
# dtype: int64
# Eğitim örnek sayısı: 5790
# Test örnek sayısı: 2475
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1769
#            1       0.68      0.54      0.60       706
#
#     accuracy                           0.80      2475
#    macro avg       0.76      0.72      0.73      2475
# weighted avg       0.79      0.80      0.79      2475
#
# Disparate impact: 7.432314410480348
# Equal opportunity diff: 0.0
# Statistical parity: 0.20861560250206537
# EO: 0.008896797153024938
# -----------------------------------
#   RESULTS for state: IL
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        22192
#               1        15644
# 1             0         6293
#               1         2707
# dtype: int64
# Eğitim örnek sayısı: 46836
# Test örnek sayısı: 20180
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82     12158
#            1       0.72      0.71      0.72      8022
#
#     accuracy                           0.78     20180
#    macro avg       0.77      0.77      0.77     20180
# weighted avg       0.78      0.78      0.78     20180
#
# Disparate impact: 1.5429612082210604
# Equal opportunity diff: 0.005749599583180564
# Statistical parity: 0.14746914107538356
# EO: 0.02211567560759104
# -----------------------------------
#   RESULTS for state: IN
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        14796
#               1         7020
# 1             0         2175
#               1          585
# dtype: int64
# Eğitim örnek sayısı: 24576
# Test örnek sayısı: 10446
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      7264
#            1       0.70      0.59      0.64      3182
#
#     accuracy                           0.80     10446
#    macro avg       0.77      0.74      0.75     10446
# weighted avg       0.79      0.80      0.79     10446
#
# Disparate impact: 1.8353333483710406
# Equal opportunity diff: 0.002250562640660165
# Statistical parity: 0.1231168259809931
# EO: 0.005835758295535462
# -----------------------------------
#   RESULTS for state: IA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        7971
#               1        3692
# 1             0         565
#               1         103
# dtype: int64
# Eğitim örnek sayısı: 12331
# Test örnek sayısı: 5414
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      3754
#            1       0.70      0.61      0.66      1660
#
#     accuracy                           0.80      5414
#    macro avg       0.77      0.75      0.76      5414
# weighted avg       0.80      0.80      0.80      5414
#
# Disparate impact: 3.0411911153771163
# Equal opportunity diff: 0.0008152173913043478
# Statistical parity: 0.18621392631510536
# EO: 0.0421248453154375
# -----------------------------------
#   RESULTS for state: KS
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6650
#               1        3193
# 1             0         993
#               1         298
# dtype: int64
# Eğitim örnek sayısı: 11134
# Test örnek sayısı: 4673
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      3226
#            1       0.70      0.59      0.64      1447
#
#     accuracy                           0.79      4673
#    macro avg       0.76      0.74      0.75      4673
# weighted avg       0.79      0.79      0.79      4673
#
# Disparate impact: 1.5018555881953228
# Equal opportunity diff: 0.0006618133686300463
# Statistical parity: 0.0898262920505247
# EO: 0.004189391094335758
# -----------------------------------
#   RESULTS for state: KY
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        9379
#               1        4475
# 1             0        1245
#               1         281
# dtype: int64
# Eğitim örnek sayısı: 15380
# Test örnek sayısı: 6626
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      4540
#            1       0.71      0.58      0.64      2086
#
#     accuracy                           0.79      6626
#    macro avg       0.76      0.74      0.75      6626
# weighted avg       0.79      0.79      0.79      6626
#
# Disparate impact: 3.7833056202194877
# Equal opportunity diff: 0.001160631383472609
# Statistical parity: 0.2046548250161388
# EO: 0.030259479268069517
# -----------------------------------
#   RESULTS for state: LA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6305
#               1        4010
# 1             0        3359
#               1         857
# dtype: int64
# Eğitim örnek sayısı: 14531
# Test örnek sayısı: 6136
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      4132
#            1       0.70      0.61      0.65      2004
#
#     accuracy                           0.79      6136
#    macro avg       0.76      0.74      0.75      6136
# weighted avg       0.78      0.79      0.78      6136
#
# Disparate impact: 3.566027463553324
# Equal opportunity diff: 0.0021826118588577663
# Statistical parity: 0.2608794587945879
# EO: 0.052446063333335596
# -----------------------------------
#   RESULTS for state: ME
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3197
#               1        1499
# 1             0         201
#               1          37
# dtype: int64
# Eğitim örnek sayısı: 4934
# Test örnek sayısı: 2068
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      1481
#            1       0.67      0.59      0.63       587
#
#     accuracy                           0.80      2068
#    macro avg       0.76      0.74      0.74      2068
# weighted avg       0.79      0.80      0.80      2068
#
# Disparate impact: 5.609178990311066
# Equal opportunity diff: 0.0
# Statistical parity: 0.2153821958089283
# EO: 0.13804018717313515
# -----------------------------------
#   RESULTS for state: MD
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6870
#               1        7850
# 1             0        4988
#               1        3430
# dtype: int64
# Eğitim örnek sayısı: 23138
# Test örnek sayısı: 9904
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79      5152
#            1       0.77      0.77      0.77      4752
#
#     accuracy                           0.78      9904
#    macro avg       0.78      0.78      0.78      9904
# weighted avg       0.78      0.78      0.78      9904
#
# Disparate impact: 1.4910514461021163
# Equal opportunity diff: 0.003357189741186796
# Statistical parity: 0.18016508229401784
# EO: 0.009836845047897547
# -----------------------------------
#   RESULTS for state: MA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11757
#               1        11282
# 1             0         3175
#               1         1753
# dtype: int64
# Eğitim örnek sayısı: 27967
# Test örnek sayısı: 12147
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80      6391
#            1       0.78      0.79      0.78      5756
#
#     accuracy                           0.79     12147
#    macro avg       0.79      0.79      0.79     12147
# weighted avg       0.79      0.79      0.79     12147
#
# Disparate impact: 1.5901425527590192
# Equal opportunity diff: 0.001986618086393409
# Statistical parity: 0.190944382331745
# EO: 0.00828616380823292
# -----------------------------------
#   RESULTS for state: MI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        19652
#               1        10632
# 1             0         3490
#               1         1259
# dtype: int64
# Eğitim örnek sayısı: 35033
# Test örnek sayısı: 14975
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85     10005
#            1       0.72      0.65      0.68      4970
#
#     accuracy                           0.80     14975
#    macro avg       0.77      0.76      0.77     14975
# weighted avg       0.79      0.80      0.80     14975
#
# Disparate impact: 1.6141426750055143
# Equal opportunity diff: 0.004013426256918019
# Statistical parity: 0.12065732352381064
# EO: 0.02102619106371644
# -----------------------------------
#   RESULTS for state: MN
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        12061
#               1         7718
# 1             0         1504
#               1          399
# dtype: int64
# Eğitim örnek sayısı: 21682
# Test örnek sayısı: 9339
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      5906
#            1       0.71      0.67      0.69      3433
#
#     accuracy                           0.78      9339
#    macro avg       0.76      0.76      0.76      9339
# weighted avg       0.78      0.78      0.78      9339
#
# Disparate impact: 2.331271745979562
# Equal opportunity diff: 0.0041400075272864136
# Statistical parity: 0.20996057250877667
# EO: 0.02945894591768601
# -----------------------------------
#   RESULTS for state: MS
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        4019
#               1        1981
# 1             0        2625
#               1         515
# dtype: int64
# Eğitim örnek sayısı: 9140
# Test örnek sayısı: 4049
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      2990
#            1       0.66      0.50      0.57      1059
#
#     accuracy                           0.80      4049
#    macro avg       0.75      0.70      0.72      4049
# weighted avg       0.79      0.80      0.79      4049
#
# Disparate impact: 4.01081690330395
# Equal opportunity diff: 0.0010065425264217413
# Statistical parity: 0.19669776354175772
# EO: 0.026124458586525845
# -----------------------------------
#   RESULTS for state: MO
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        13434
#               1         6247
# 1             0         1929
#               1          603
# dtype: int64
# Eğitim örnek sayısı: 22213
# Test örnek sayısı: 9451
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      6544
#            1       0.69      0.59      0.64      2907
#
#     accuracy                           0.79      9451
#    macro avg       0.76      0.74      0.75      9451
# weighted avg       0.79      0.79      0.79      9451
#
# Disparate impact: 1.572974325985796
# Equal opportunity diff: 0.0006793421459686791
# Statistical parity: 0.09853016446858548
# EO: 0.0152606812964597
# -----------------------------------
#   RESULTS for state: MT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        2373
#               1        1043
# 1             0         244
#               1          65
# dtype: int64
# Eğitim örnek sayısı: 3725
# Test örnek sayısı: 1738
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1248
#            1       0.66      0.55      0.60       490
#
#     accuracy                           0.79      1738
#    macro avg       0.75      0.72      0.73      1738
# weighted avg       0.79      0.79      0.79      1738
#
# Disparate impact: 1.3800031269543465
# Equal opportunity diff: 0.0
# Statistical parity: 0.06561205069715334
# EO: 0.01869109947643982
# -----------------------------------
#   RESULTS for state: NE
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        4664
#               1        2212
# 1             0         520
#               1         126
# dtype: int64
# Eğitim örnek sayısı: 7522
# Test örnek sayısı: 3263
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84      2233
#            1       0.68      0.54      0.60      1030
#
#     accuracy                           0.78      3263
#    macro avg       0.74      0.71      0.72      3263
# weighted avg       0.77      0.78      0.77      3263
#
# Disparate impact: 4.4337520459072
# Equal opportunity diff: 0.0013780431786862655
# Statistical parity: 0.20847780278722283
# EO: 0.024744714999875284
# -----------------------------------
#   RESULTS for state: NV
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        4283
#               1        2721
# 1             0        2582
#               1         763
# dtype: int64
# Eğitim örnek sayısı: 10349
# Test örnek sayısı: 4458
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      2957
#            1       0.72      0.61      0.66      1501
#
#     accuracy                           0.79      4458
#    macro avg       0.77      0.75      0.75      4458
# weighted avg       0.78      0.79      0.78      4458
#
# Disparate impact: 2.2856059076440687
# Equal opportunity diff: 0.002269007415687807
# Statistical parity: 0.198467073268278
# EO: 0.012122571703921059
# -----------------------------------
#   RESULTS for state: NH
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3154
#               1        2111
# 1             0         226
#               1          93
# dtype: int64
# Eğitim örnek sayısı: 5584
# Test örnek sayısı: 2382
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      1400
#            1       0.75      0.70      0.73       982
#
#     accuracy                           0.78      2382
#    macro avg       0.78      0.77      0.77      2382
# weighted avg       0.78      0.78      0.78      2382
#
# Disparate impact: 2.058347375028909
# Equal opportunity diff: 0.0014847809948032665
# Statistical parity: 0.2041098508984325
# EO: 0.004653005022541321
# -----------------------------------
#   RESULTS for state: NJ
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        11689
#               1        12702
# 1             0         5346
#               1         3586
# dtype: int64
# Eğitim örnek sayısı: 33323
# Test örnek sayısı: 14458
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80      7316
#            1       0.80      0.80      0.80      7142
#
#     accuracy                           0.80     14458
#    macro avg       0.80      0.80      0.80     14458
# weighted avg       0.80      0.80      0.80     14458
#
# Disparate impact: 1.3938956715041362
# Equal opportunity diff: 0.008271656302005782
# Statistical parity: 0.15252504403561612
# EO: 0.010585313019724214
# -----------------------------------
#   RESULTS for state: NM
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        2962
#               1        1502
# 1             0        1331
#               1         317
# dtype: int64
# Eğitim örnek sayısı: 6112
# Test örnek sayısı: 2599
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1825
#            1       0.72      0.56      0.63       774
#
#     accuracy                           0.80      2599
#    macro avg       0.78      0.73      0.75      2599
# weighted avg       0.80      0.80      0.80      2599
#
# Disparate impact: 3.320816899406602
# Equal opportunity diff: 0.0
# Statistical parity: 0.19815947476843632
# EO: 0.012723717852308636
# -----------------------------------
#   RESULTS for state: NY
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        28559
#               1        23129
# 1             0        13697
#               1         6768
# dtype: int64
# Eğitim örnek sayısı: 72153
# Test örnek sayısı: 30868
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81     18038
#            1       0.74      0.70      0.72     12830
#
#     accuracy                           0.77     30868
#    macro avg       0.77      0.76      0.76     30868
# weighted avg       0.77      0.77      0.77     30868
#
# Disparate impact: 1.6144190846441862
# Equal opportunity diff: 0.010392560018177352
# Statistical parity: 0.16841067475850652
# EO: 0.02608110221197091
# -----------------------------------
#   RESULTS for state: NC
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        17400
#               1         9956
# 1             0         7317
#               1         1891
# dtype: int64
# Eğitim örnek sayısı: 36564
# Test örnek sayısı: 15503
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85     10370
#            1       0.72      0.60      0.65      5133
#
#     accuracy                           0.79     15503
#    macro avg       0.77      0.74      0.75     15503
# weighted avg       0.79      0.79      0.79     15503
#
# Disparate impact: 2.282153450170948
# Equal opportunity diff: 0.0027525709699695775
# Statistical parity: 0.18028215437130204
# EO: 0.03265303895948444
# -----------------------------------
#   RESULTS for state: ND
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1768
#               1        1092
# 1             0         211
#               1          58
# dtype: int64
# Eğitim örnek sayısı: 3129
# Test örnek sayısı: 1326
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       840
#            1       0.70      0.61      0.65       486
#
#     accuracy                           0.76      1326
#    macro avg       0.75      0.73      0.74      1326
# weighted avg       0.76      0.76      0.76      1326
#
# Disparate impact: 3.8857142857142857
# Equal opportunity diff: 0.001277139208173691
# Statistical parity: 0.2546218487394958
# EO: 0.0006385696040868455
# -----------------------------------
#   RESULTS for state: OH
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        24304
#               1        13562
# 1             0         4329
#               1         1237
# dtype: int64
# Eğitim örnek sayısı: 43432
# Test örnek sayısı: 18703
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85     12396
#            1       0.72      0.63      0.68      6307
#
#     accuracy                           0.79     18703
#    macro avg       0.77      0.76      0.76     18703
# weighted avg       0.79      0.79      0.79     18703
#
# Disparate impact: 2.3400738631498976
# Equal opportunity diff: 0.0027262705407772895
# Statistical parity: 0.18263996296327545
# EO: 0.03533464134049111
# -----------------------------------
#   RESULTS for state: OK
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6448
#               1        2908
# 1             0        2527
#               1         652
# dtype: int64
# Eğitim örnek sayısı: 12535
# Test örnek sayısı: 5382
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      3883
#            1       0.68      0.52      0.59      1499
#
#     accuracy                           0.80      5382
#    macro avg       0.76      0.72      0.73      5382
# weighted avg       0.79      0.80      0.79      5382
#
# Disparate impact: 2.027207477883492
# Equal opportunity diff: 0.0013351134846461949
# Statistical parity: 0.12433058810117194
# EO: 0.017735400294596186
# -----------------------------------
#   RESULTS for state: OR
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        8240
#               1        4980
# 1             0        1499
#               1         568
# dtype: int64
# Eğitim örnek sayısı: 15287
# Test örnek sayısı: 6632
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      4191
#            1       0.74      0.66      0.70      2441
#
#     accuracy                           0.79      6632
#    macro avg       0.78      0.76      0.77      6632
# weighted avg       0.79      0.79      0.79      6632
#
# Disparate impact: 1.8432538849747664
# Equal opportunity diff: 0.001352780023985304
# Statistical parity: 0.1614545184579695
# EO: 0.010709150044752699
# -----------------------------------
#   RESULTS for state: PA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        26679
#               1        15717
# 1             0         4067
#               1         1429
# dtype: int64
# Eğitim örnek sayısı: 47892
# Test örnek sayısı: 20416
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84     13177
#            1       0.72      0.67      0.69      7239
#
#     accuracy                           0.79     20416
#    macro avg       0.77      0.76      0.77     20416
# weighted avg       0.79      0.79      0.79     20416
#
# Disparate impact: 1.5397457024387426
# Equal opportunity diff: 0.001489135998457008
# Statistical parity: 0.12026038108058293
# EO: 0.02524357825255918
# -----------------------------------
#   RESULTS for state: RI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1906
#               1        1526
# 1             0         423
#               1         140
# dtype: int64
# Eğitim örnek sayısı: 3995
# Test örnek sayısı: 1717
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       980
#            1       0.74      0.75      0.75       737
#
#     accuracy                           0.78      1717
#    macro avg       0.78      0.78      0.78      1717
# weighted avg       0.78      0.78      0.78      1717
#
# Disparate impact: 2.4064215985356925
# Equal opportunity diff: -0.00546448087431694
# Statistical parity: 0.2726103539011915
# EO: 0.012661156571239559
# -----------------------------------
#   RESULTS for state: SC
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        8232
#               1        4633
# 1             0        3733
#               1         722
# dtype: int64
# Eğitim örnek sayısı: 17320
# Test örnek sayısı: 7559
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      5274
#            1       0.69      0.62      0.65      2285
#
#     accuracy                           0.80      7559
#    macro avg       0.77      0.75      0.76      7559
# weighted avg       0.80      0.80      0.80      7559
#
# Disparate impact: 3.9248400945717057
# Equal opportunity diff: 0.002412868632707775
# Statistical parity: 0.2479193631904254
# EO: 0.040437011789062914
# -----------------------------------
#   RESULTS for state: SD
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        2178
#               1         910
# 1             0         307
#               1          43
# dtype: int64
# Eğitim örnek sayısı: 3438
# Test örnek sayısı: 1461
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1091
#            1       0.62      0.46      0.53       370
#
#     accuracy                           0.79      1461
#    macro avg       0.73      0.68      0.70      1461
# weighted avg       0.78      0.79      0.78      1461
#
# Disparate impact: 0
# Equal opportunity diff: 0.0009596928982725527
# Statistical parity: 0.20684410646387832
# EO: 0
# -----------------------------------
#   RESULTS for state: TN
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        13365
#               1         6544
# 1             0         3043
#               1          829
# dtype: int64
# Eğitim örnek sayısı: 23781
# Test örnek sayısı: 10222
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      7140
#            1       0.70      0.60      0.65      3082
#
#     accuracy                           0.80     10222
#    macro avg       0.77      0.74      0.75     10222
# weighted avg       0.80      0.80      0.80     10222
#
# Disparate impact: 1.5886166096115604
# Equal opportunity diff: 0.0014230841462881316
# Statistical parity: 0.10118991831900367
# EO: 0.005610576675148925
# -----------------------------------
#   RESULTS for state: TX
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        45570
#               1        28422
# 1             0        14786
#               1         6208
# dtype: int64
# Eğitim örnek sayısı: 94986
# Test örnek sayısı: 40938
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84     25983
#            1       0.73      0.66      0.69     14955
#
#     accuracy                           0.79     40938
#    macro avg       0.77      0.76      0.76     40938
# weighted avg       0.78      0.79      0.78     40938
#
# Disparate impact: 1.3764941532015427
# Equal opportunity diff: 0.004985014320764338
# Statistical parity: 0.0959966950274192
# EO: 0.021043082962866375
# -----------------------------------
#   RESULTS for state: UT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        6755
#               1        3538
# 1             0         952
#               1         265
# dtype: int64
# Eğitim örnek sayısı: 11510
# Test örnek sayısı: 4827
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      3176
#            1       0.77      0.69      0.72      1651
#
#     accuracy                           0.82      4827
#    macro avg       0.81      0.79      0.80      4827
# weighted avg       0.82      0.82      0.82      4827
#
# Disparate impact: 2.075323475046211
# Equal opportunity diff: 0.0013740982480247338
# Statistical parity: 0.1680866353779648
# EO: 0.007188460556616498
# -----------------------------------
#   RESULTS for state: VT
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1612
#               1         898
# 1             0          77
#               1          25
# dtype: int64
# Eğitim örnek sayısı: 2612
# Test örnek sayısı: 1155
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       785
#            1       0.65      0.61      0.63       370
#
#     accuracy                           0.77      1155
#    macro avg       0.73      0.73      0.73      1155
# weighted avg       0.77      0.77      0.77      1155
#
# Disparate impact: 2.1848021582733814
# Equal opportunity diff: 0.0
# Statistical parity: 0.16532123138698343
# EO: 0.0029325513196480912
# -----------------------------------
#   RESULTS for state: VA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        12659
#               1        11146
# 1             0         5575
#               1         2941
# dtype: int64
# Eğitim örnek sayısı: 32321
# Test örnek sayısı: 13823
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      7743
#            1       0.78      0.75      0.76      6080
#
#     accuracy                           0.80     13823
#    macro avg       0.79      0.79      0.79     13823
# weighted avg       0.80      0.80      0.80     13823
#
# Disparate impact: 1.47989897818224
# Equal opportunity diff: 0.0022512478579558605
# Statistical parity: 0.1491705028793857
# EO: 0.011283293791804776
# -----------------------------------
#   RESULTS for state: WA
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        12149
#               1         9796
# 1             0         3853
#               1         2133
# dtype: int64
# Eğitim örnek sayısı: 27931
# Test örnek sayısı: 12013
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      6832
#            1       0.75      0.74      0.74      5181
#
#     accuracy                           0.78     12013
#    macro avg       0.78      0.78      0.78     12013
# weighted avg       0.78      0.78      0.78     12013
#
# Disparate impact: 1.434892421264717
# Equal opportunity diff: 0.0033458469600710907
# Statistical parity: 0.13681821968687385
# EO: 0.0043035030867027285
# -----------------------------------
#   RESULTS for state: WV
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3816
#               1        1597
# 1             0         231
#               1          71
# dtype: int64
# Eğitim örnek sayısı: 5715
# Test örnek sayısı: 2388
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1701
#            1       0.68      0.55      0.61       687
#
#     accuracy                           0.79      2388
#    macro avg       0.75      0.72      0.73      2388
# weighted avg       0.79      0.79      0.79      2388
#
# Disparate impact: 2.4657168299198577
# Equal opportunity diff: 0.0
# Statistical parity: 0.14450729309069016
# EO: 0.0036363636363636598
# -----------------------------------
#   RESULTS for state: WI
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        13808
#               1         7467
# 1             0         1303
#               1          346
# dtype: int64
# Eğitim örnek sayısı: 22924
# Test örnek sayısı: 9766
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84      6422
#            1       0.71      0.64      0.68      3344
#
#     accuracy                           0.79      9766
#    macro avg       0.77      0.75      0.76      9766
# weighted avg       0.79      0.79      0.79      9766
#
# Disparate impact: 2.4201174760104682
# Equal opportunity diff: 0.003937653814602133
# Statistical parity: 0.18842340812988057
# EO: 0.014616881052817186
# -----------------------------------
#   RESULTS for state: WY
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        1236
#               1         723
# 1             0         147
#               1          37
# dtype: int64
# Eğitim örnek sayısı: 2143
# Test örnek sayısı: 921
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       585
#            1       0.70      0.62      0.66       336
#
#     accuracy                           0.77       921
#    macro avg       0.75      0.73      0.74       921
# weighted avg       0.76      0.77      0.76       921
#
# Disparate impact: 1.6470588235294117
# Equal opportunity diff: 0.0
# Statistical parity: 0.13095238095238093
# EO: 0.0
# -----------------------------------
#   RESULTS for state: PR
# -----------------------------------
# Race Dağılımı Train:
# RAC1P_others  PINCP
# 0             0        3646
#               1         512
# 1             0        1968
#               1         164
# dtype: int64
# Eğitim örnek sayısı: 6290
# Test örnek sayısı: 2781
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      2495
#            1       0.65      0.28      0.40       286
#
#     accuracy                           0.91      2781
#    macro avg       0.79      0.63      0.67      2781
# weighted avg       0.90      0.91      0.89      2781
#
# Disparate impact: 1.7359407407407408
# Equal opportunity diff: 0.0
# Statistical parity: 0.021932008830022075
# EO: 0.020563112938943362
