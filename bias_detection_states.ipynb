# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from model.preprocess import ACSIncomePreprocess
from model.model import ACSIncomeModel
from utils.constants import states

# %%
preprocess = ACSIncomePreprocess()
model = ACSIncomeModel()

# %% [markdown]
# ## Bias Metrics Calculation for each State

# %%
train, test = preprocess.get_preprocessed_data()

# %%
for state in states:
  model.print_model_metrics_for_state(train, test, state)
# Out:
# -----------------------------------
#   RESULTS for state: AL
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        4848
#             1        3266
# 1           0        5978
#             1        1535
# dtype: int64
# Eğitim örnek sayısı: 15627
# Test örnek sayısı: 6641
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      4518
#            1       0.72      0.60      0.65      2123
#
#     accuracy                           0.80      6641
#    macro avg       0.77      0.74      0.75      6641
# weighted avg       0.79      0.80      0.79      6641
#
# Number of males: 3508
# Number of females: 3133
# True Positive Unpriviliged:0
# False Positive Unpriviliged:375
# True Positive Priviliged:4
# False Positive Priviliged:1374
# True Negative Unpriviliged:28
# False Negative Unpriviliged:2730
# True Negative Priviliged:19
# False Negative Priviliged:2111
# Number of males: 3508
# Number of females: 3133
# True Positive Unpriviliged:0
# False Positive Unpriviliged:375
# True Positive Priviliged:4
# False Positive Priviliged:1374
# True Negative Unpriviliged:28
# False Negative Unpriviliged:2730
# True Negative Priviliged:19
# False Negative Priviliged:2111
# Disparate impact: 3.281850247054352
# Equal opportunity diff: 0.0018912529550827422
# Statistical parity: 0.2731228351884398
# EO: 0.028865267219357504
# -----------------------------------
#   RESULTS for state: AK
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        763
#             1        609
# 1           0        739
#             1        358
# dtype: int64
# Eğitim örnek sayısı: 2469
# Test örnek sayısı: 1077
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       673
#            1       0.70      0.67      0.69       404
#
#     accuracy                           0.77      1077
#    macro avg       0.75      0.75      0.75      1077
# weighted avg       0.77      0.77      0.77      1077
#
# Number of males: 582
# Number of females: 495
# True Positive Unpriviliged:1
# False Positive Unpriviliged:119
# True Positive Priviliged:0
# False Positive Priviliged:264
# True Negative Unpriviliged:1
# False Negative Unpriviliged:374
# True Negative Priviliged:1
# False Negative Priviliged:317
# Number of males: 582
# Number of females: 495
# True Positive Unpriviliged:1
# False Positive Unpriviliged:119
# True Positive Priviliged:0
# False Positive Priviliged:264
# True Negative Unpriviliged:1
# False Negative Unpriviliged:374
# True Negative Priviliged:1
# False Negative Priviliged:317
# Disparate impact: 1.8711340206185567
# Equal opportunity diff: -0.0026666666666666666
# Statistical parity: 0.21118400499843798
# EO: 0.0036132075471697967
# -----------------------------------
#   RESULTS for state: AZ
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        7324
#             1        4924
# 1           0        8046
#             1        2999
# dtype: int64
# Eğitim örnek sayısı: 23293
# Test örnek sayısı: 9984
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      6607
#            1       0.70      0.64      0.67      3377
#
#     accuracy                           0.79      9984
#    macro avg       0.76      0.75      0.76      9984
# weighted avg       0.78      0.79      0.78      9984
#
# Number of males: 5277
# Number of females: 4707
# True Positive Unpriviliged:9
# False Positive Unpriviliged:948
# True Positive Priviliged:13
# False Positive Priviliged:2105
# True Negative Unpriviliged:47
# False Negative Unpriviliged:3703
# True Negative Priviliged:35
# False Negative Priviliged:3124
# Number of males: 5277
# Number of females: 4707
# True Positive Unpriviliged:9
# False Positive Unpriviliged:948
# True Positive Priviliged:13
# False Positive Priviliged:2105
# True Negative Unpriviliged:47
# False Negative Unpriviliged:3703
# True Negative Priviliged:35
# False Negative Priviliged:3124
# Disparate impact: 1.9741089711488253
# Equal opportunity diff: 0.0017195177415277063
# Statistical parity: 0.19805019872305626
# EO: 0.01630027922956724
# -----------------------------------
#   RESULTS for state: AR
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        3334
#             1        1721
# 1           0        3808
#             1         929
# dtype: int64
# Eğitim örnek sayısı: 9792
# Test örnek sayısı: 4137
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      3054
#            1       0.67      0.53      0.59      1083
#
#     accuracy                           0.81      4137
#    macro avg       0.76      0.72      0.73      4137
# weighted avg       0.80      0.81      0.80      4137
#
# Number of males: 2143
# Number of females: 1994
# True Positive Unpriviliged:0
# False Positive Unpriviliged:196
# True Positive Priviliged:2
# False Positive Priviliged:654
# True Negative Unpriviliged:13
# False Negative Unpriviliged:1785
# True Negative Priviliged:8
# False Negative Priviliged:1479
# Number of males: 2143
# Number of females: 1994
# True Positive Unpriviliged:0
# False Positive Unpriviliged:196
# True Positive Priviliged:2
# False Positive Priviliged:654
# True Negative Unpriviliged:13
# False Negative Unpriviliged:1785
# True Negative Priviliged:8
# False Negative Priviliged:1479
# Disparate impact: 3.11423047987277
# Equal opportunity diff: 0.0013504388926401081
# Statistical parity: 0.20781804115098443
# EO: 0.025733401842712014
# -----------------------------------
#   RESULTS for state: CA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        38581
#             1        33763
# 1           0        42127
#             1        22572
# dtype: int64
# Eğitim örnek sayısı: 137043
# Test örnek sayısı: 58622
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82     34622
#            1       0.75      0.73      0.74     24000
#
#     accuracy                           0.79     58622
#    macro avg       0.78      0.78      0.78     58622
# weighted avg       0.79      0.79      0.79     58622
#
# Number of males: 30967
# Number of females: 27655
# True Positive Unpriviliged:424
# False Positive Unpriviliged:8486
# True Positive Priviliged:706
# False Positive Priviliged:13769
# True Negative Unpriviliged:1299
# False Negative Unpriviliged:17446
# True Negative Priviliged:1112
# False Negative Priviliged:15380
# Number of males: 30967
# Number of females: 27655
# True Positive Unpriviliged:424
# False Positive Unpriviliged:8486
# True Positive Priviliged:706
# False Positive Priviliged:13769
# True Negative Unpriviliged:1299
# False Negative Unpriviliged:17446
# True Negative Priviliged:1112
# False Negative Priviliged:15380
# Disparate impact: 1.4508262243754864
# Equal opportunity diff: 0.02016217948838368
# Statistical parity: 0.1452490204008528
# EO: 0.03909511712413819
# -----------------------------------
#   RESULTS for state: CO
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        5917
#             1        5683
# 1           0        6949
#             1        3486
# dtype: int64
# Eğitim örnek sayısı: 22035
# Test örnek sayısı: 9271
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      5468
#            1       0.73      0.71      0.72      3803
#
#     accuracy                           0.77      9271
#    macro avg       0.76      0.76      0.76      9271
# weighted avg       0.77      0.77      0.77      9271
#
# Number of males: 4979
# Number of females: 4292
# True Positive Unpriviliged:8
# False Positive Unpriviliged:1200
# True Positive Priviliged:4
# False Positive Priviliged:2483
# True Negative Unpriviliged:40
# False Negative Unpriviliged:3044
# True Negative Priviliged:17
# False Negative Priviliged:2475
# Number of males: 4979
# Number of females: 4292
# True Positive Unpriviliged:8
# False Positive Unpriviliged:1200
# True Positive Priviliged:4
# False Positive Priviliged:2483
# True Negative Unpriviliged:40
# False Negative Unpriviliged:3044
# True Negative Priviliged:17
# False Negative Priviliged:2475
# Disparate impact: 1.7747060834312058
# Equal opportunity diff: -0.0010076781266703217
# Statistical parity: 0.21804402348203555
# EO: 0.013232871321399648
# -----------------------------------
#   RESULTS for state: CT
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        3188
#             1        3917
# 1           0        4123
#             1        2751
# dtype: int64
# Eğitim örnek sayısı: 13979
# Test örnek sayısı: 5806
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79      3011
#            1       0.78      0.77      0.78      2795
#
#     accuracy                           0.79      5806
#    macro avg       0.79      0.79      0.79      5806
# weighted avg       0.79      0.79      0.79      5806
#
# Number of males: 2939
# Number of females: 2867
# True Positive Unpriviliged:4
# False Positive Unpriviliged:1138
# True Positive Priviliged:11
# False Positive Priviliged:1626
# True Negative Unpriviliged:6
# False Negative Unpriviliged:1719
# True Negative Priviliged:7
# False Negative Priviliged:1295
# Number of males: 2939
# Number of females: 2867
# True Positive Unpriviliged:4
# False Positive Unpriviliged:1138
# True Positive Priviliged:11
# False Positive Priviliged:1626
# True Negative Unpriviliged:6
# False Negative Unpriviliged:1719
# True Negative Priviliged:7
# False Negative Priviliged:1295
# Disparate impact: 1.398333242957056
# Equal opportunity diff: 0.006101132413549145
# Statistical parity: 0.15866639813636485
# EO: 0.0035296492792440386
# -----------------------------------
#   RESULTS for state: DE
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0         891
#             1         785
# 1           0        1131
#             1         526
# dtype: int64
# Eğitim örnek sayısı: 3333
# Test örnek sayısı: 1380
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       853
#            1       0.71      0.68      0.69       527
#
#     accuracy                           0.77      1380
#    macro avg       0.76      0.75      0.75      1380
# weighted avg       0.77      0.77      0.77      1380
#
# Number of males: 701
# Number of females: 679
# True Positive Unpriviliged:0
# False Positive Unpriviliged:182
# True Positive Priviliged:0
# False Positive Priviliged:322
# True Negative Unpriviliged:1
# False Negative Unpriviliged:496
# True Negative Priviliged:0
# False Negative Priviliged:379
# Number of males: 701
# Number of females: 679
# True Positive Unpriviliged:0
# False Positive Unpriviliged:182
# True Positive Priviliged:0
# False Positive Priviliged:322
# True Negative Unpriviliged:1
# False Negative Unpriviliged:496
# True Negative Priviliged:0
# False Negative Priviliged:379
# Disparate impact: 1.7137056951607594
# Equal opportunity diff: 0.0
# Statistical parity: 0.19130255746577057
# EO: 0.002732240437158473
# -----------------------------------
#   RESULTS for state: FL
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        21322
#             1        14198
# 1           0        24907
#             1         8828
# dtype: int64
# Eğitim örnek sayısı: 69255
# Test örnek sayısı: 29670
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84     19920
#            1       0.69      0.63      0.66      9750
#
#     accuracy                           0.79     29670
#    macro avg       0.76      0.75      0.75     29670
# weighted avg       0.78      0.79      0.78     29670
#
# Number of males: 15302
# Number of females: 14368
# True Positive Unpriviliged:55
# False Positive Unpriviliged:2787
# True Positive Priviliged:119
# False Positive Priviliged:5895
# True Negative Unpriviliged:478
# False Negative Unpriviliged:11048
# True Negative Priviliged:356
# False Negative Priviliged:8932
# Number of males: 15302
# Number of females: 14368
# True Positive Unpriviliged:55
# False Positive Unpriviliged:2787
# True Positive Priviliged:119
# False Positive Priviliged:5895
# True Negative Unpriviliged:478
# False Negative Unpriviliged:11048
# True Negative Priviliged:356
# False Negative Priviliged:8932
# Disparate impact: 1.9869524398801293
# Equal opportunity diff: 0.008194102344363357
# Statistical parity: 0.19521985204199108
# EO: 0.048822219800637556
# -----------------------------------
#   RESULTS for state: GA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        10662
#             1         7830
# 1           0        12367
#             1         4783
# dtype: int64
# Eğitim örnek sayısı: 35642
# Test örnek sayısı: 15273
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85      9841
#            1       0.73      0.67      0.70      5432
#
#     accuracy                           0.80     15273
#    macro avg       0.78      0.77      0.77     15273
# weighted avg       0.79      0.80      0.79     15273
#
# Number of males: 7886
# Number of females: 7387
# True Positive Unpriviliged:15
# False Positive Unpriviliged:1615
# True Positive Priviliged:33
# False Positive Priviliged:3295
# True Negative Unpriviliged:125
# False Negative Unpriviliged:5632
# True Negative Priviliged:83
# False Negative Priviliged:4475
# Number of males: 7886
# Number of females: 7387
# True Positive Unpriviliged:15
# False Positive Unpriviliged:1615
# True Positive Priviliged:33
# False Positive Priviliged:3295
# True Negative Unpriviliged:125
# False Negative Unpriviliged:5632
# True Negative Priviliged:83
# False Negative Priviliged:4475
# Disparate impact: 1.9125246417896746
# Equal opportunity diff: 0.004664041762561616
# Statistical parity: 0.2013557826068999
# EO: 0.025966185149058123
# -----------------------------------
#   RESULTS for state: HI
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1587
#             1        1298
# 1           0        1716
#             1         823
# dtype: int64
# Eğitim örnek sayısı: 5424
# Test örnek sayısı: 2307
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1481
#            1       0.70      0.66      0.68       826
#
#     accuracy                           0.78      2307
#    macro avg       0.76      0.75      0.75      2307
# weighted avg       0.77      0.78      0.77      2307
#
# Number of males: 1188
# Number of females: 1119
# True Positive Unpriviliged:1
# False Positive Unpriviliged:261
# True Positive Priviliged:0
# False Positive Priviliged:525
# True Negative Unpriviliged:3
# False Negative Unpriviliged:854
# True Negative Priviliged:1
# False Negative Priviliged:662
# Number of males: 1188
# Number of females: 1119
# True Positive Unpriviliged:1
# False Positive Unpriviliged:261
# True Positive Priviliged:0
# False Positive Priviliged:525
# True Negative Unpriviliged:3
# False Negative Unpriviliged:854
# True Negative Priviliged:1
# False Negative Priviliged:662
# Disparate impact: 1.8874334952579228
# Equal opportunity diff: -0.0011695906432748538
# Statistical parity: 0.20778156904162268
# EO: 0.0053160431612503
# -----------------------------------
#   RESULTS for state: ID
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1959
#             1        1201
# 1           0        2151
#             1         479
# dtype: int64
# Eğitim örnek sayısı: 5790
# Test örnek sayısı: 2475
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1769
#            1       0.68      0.56      0.61       706
#
#     accuracy                           0.80      2475
#    macro avg       0.76      0.73      0.74      2475
# weighted avg       0.79      0.80      0.79      2475
#
# Number of males: 1344
# Number of females: 1131
# True Positive Unpriviliged:0
# False Positive Unpriviliged:109
# True Positive Priviliged:0
# False Positive Priviliged:465
# True Negative Unpriviliged:7
# False Negative Unpriviliged:1015
# True Negative Priviliged:3
# False Negative Priviliged:876
# Number of males: 1344
# Number of females: 1131
# True Positive Unpriviliged:0
# False Positive Unpriviliged:109
# True Positive Priviliged:0
# False Positive Priviliged:465
# True Negative Unpriviliged:7
# False Negative Unpriviliged:1015
# True Negative Priviliged:3
# False Negative Priviliged:876
# Disparate impact: 3.589961500655308
# Equal opportunity diff: 0.0
# Statistical parity: 0.2496072533788051
# EO: 0.02696728558797523
# -----------------------------------
#   RESULTS for state: IL
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        12632
#             1        11543
# 1           0        15853
#             1         6808
# dtype: int64
# Eğitim örnek sayısı: 46836
# Test örnek sayısı: 20180
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82     12158
#            1       0.74      0.71      0.73      8022
#
#     accuracy                           0.79     20180
#    macro avg       0.78      0.77      0.78     20180
# weighted avg       0.78      0.79      0.79     20180
#
# Number of males: 10421
# Number of females: 9759
# True Positive Unpriviliged:26
# False Positive Unpriviliged:2610
# True Positive Priviliged:76
# False Positive Priviliged:5040
# True Negative Unpriviliged:177
# False Negative Unpriviliged:6946
# True Negative Priviliged:150
# False Negative Priviliged:5155
# Number of males: 10421
# Number of females: 9759
# True Positive Unpriviliged:26
# False Positive Unpriviliged:2610
# True Positive Priviliged:76
# False Positive Priviliged:5040
# True Negative Unpriviliged:177
# False Negative Unpriviliged:6946
# True Negative Priviliged:150
# False Negative Priviliged:5155
# Disparate impact: 1.8175277567081414
# Equal opportunity diff: 0.010799568265140743
# Statistical parity: 0.2208221300012973
# EO: 0.022703491892172644
# -----------------------------------
#   RESULTS for state: IN
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        7672
#             1        5231
# 1           0        9299
#             1        2374
# dtype: int64
# Eğitim örnek sayısı: 24576
# Test örnek sayısı: 10446
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      7264
#            1       0.70      0.58      0.63      3182
#
#     accuracy                           0.80     10446
#    macro avg       0.76      0.74      0.75     10446
# weighted avg       0.79      0.80      0.79     10446
#
# Number of males: 5461
# Number of females: 4985
# True Positive Unpriviliged:4
# False Positive Unpriviliged:570
# True Positive Priviliged:9
# False Positive Priviliged:2046
# True Negative Unpriviliged:84
# False Negative Unpriviliged:4327
# True Negative Priviliged:44
# False Negative Priviliged:3362
# Number of males: 5461
# Number of females: 4985
# True Positive Unpriviliged:4
# False Positive Unpriviliged:570
# True Positive Priviliged:9
# False Positive Priviliged:2046
# True Negative Unpriviliged:84
# False Negative Unpriviliged:4327
# True Negative Priviliged:44
# False Negative Priviliged:3362
# Disparate impact: 3.2680818116680395
# Equal opportunity diff: 0.001746256678430069
# Statistical parity: 0.2611592697888575
# EO: 0.054566996035979906
# -----------------------------------
#   RESULTS for state: IA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        3982
#             1        2539
# 1           0        4554
#             1        1256
# dtype: int64
# Eğitim örnek sayısı: 12331
# Test örnek sayısı: 5414
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      3754
#            1       0.70      0.62      0.66      1660
#
#     accuracy                           0.80      5414
#    macro avg       0.77      0.75      0.76      5414
# weighted avg       0.80      0.80      0.80      5414
#
# Number of males: 2830
# Number of females: 2584
# True Positive Unpriviliged:0
# False Positive Unpriviliged:344
# True Positive Priviliged:3
# False Positive Priviliged:1125
# True Negative Unpriviliged:19
# False Negative Unpriviliged:2221
# True Negative Priviliged:13
# False Negative Priviliged:1689
# Number of males: 2830
# Number of females: 2584
# True Positive Unpriviliged:0
# False Positive Unpriviliged:344
# True Positive Priviliged:3
# False Positive Priviliged:1125
# True Negative Unpriviliged:19
# False Negative Unpriviliged:2221
# True Negative Priviliged:13
# False Negative Priviliged:1689
# Disparate impact: 2.994034020872709
# Equal opportunity diff: 0.0017730496453900709
# Statistical parity: 0.2654596374536424
# EO: 0.02134554867682993
# -----------------------------------
#   RESULTS for state: KS
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        3574
#             1        2355
# 1           0        4069
#             1        1136
# dtype: int64
# Eğitim örnek sayısı: 11134
# Test örnek sayısı: 4673
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      3226
#            1       0.69      0.57      0.62      1447
#
#     accuracy                           0.79      4673
#    macro avg       0.76      0.73      0.74      4673
# weighted avg       0.78      0.79      0.78      4673
#
# Number of males: 2484
# Number of females: 2189
# True Positive Unpriviliged:1
# False Positive Unpriviliged:269
# True Positive Priviliged:1
# False Positive Priviliged:923
# True Negative Unpriviliged:13
# False Negative Unpriviliged:1906
# True Negative Priviliged:9
# False Negative Priviliged:1551
# Number of males: 2484
# Number of females: 2189
# True Positive Unpriviliged:1
# False Positive Unpriviliged:269
# True Positive Priviliged:1
# False Positive Priviliged:923
# True Negative Unpriviliged:13
# False Negative Unpriviliged:1906
# True Negative Priviliged:9
# False Negative Priviliged:1551
# Disparate impact: 3.0157988906781177
# Equal opportunity diff: 0.00011994604792976498
# Statistical parity: 0.24863668363777602
# EO: 0.018281292233778286
# -----------------------------------
#   RESULTS for state: KY
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        4967
#             1        3058
# 1           0        5657
#             1        1698
# dtype: int64
# Eğitim örnek sayısı: 15380
# Test örnek sayısı: 6626
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      4540
#            1       0.72      0.57      0.63      2086
#
#     accuracy                           0.79      6626
#    macro avg       0.77      0.73      0.75      6626
# weighted avg       0.79      0.79      0.79      6626
#
# Number of males: 3455
# Number of females: 3171
# True Positive Unpriviliged:0
# False Positive Unpriviliged:511
# True Positive Priviliged:4
# False Positive Priviliged:1144
# True Negative Unpriviliged:29
# False Negative Unpriviliged:2631
# True Negative Priviliged:15
# False Negative Priviliged:2292
# Number of males: 3455
# Number of females: 3171
# True Positive Unpriviliged:0
# False Positive Unpriviliged:511
# True Positive Priviliged:4
# False Positive Priviliged:1144
# True Negative Unpriviliged:29
# False Negative Unpriviliged:2631
# True Negative Priviliged:15
# False Negative Priviliged:2292
# Disparate impact: 2.061907499553952
# Equal opportunity diff: 0.0017421602787456446
# Statistical parity: 0.17112416659478696
# EO: 0.021251836219007232
# -----------------------------------
#   RESULTS for state: LA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        4116
#             1        3272
# 1           0        5548
#             1        1595
# dtype: int64
# Eğitim örnek sayısı: 14531
# Test örnek sayısı: 6136
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      4132
#            1       0.70      0.61      0.65      2004
#
#     accuracy                           0.79      6136
#    macro avg       0.76      0.74      0.75      6136
# weighted avg       0.78      0.79      0.78      6136
#
# Number of males: 3089
# Number of females: 3047
# True Positive Unpriviliged:2
# False Positive Unpriviliged:396
# True Positive Priviliged:5
# False Positive Priviliged:1354
# True Negative Unpriviliged:27
# False Negative Unpriviliged:2622
# True Negative Priviliged:17
# False Negative Priviliged:1713
# Number of males: 3089
# Number of females: 3047
# True Positive Unpriviliged:2
# False Positive Unpriviliged:396
# True Positive Priviliged:5
# False Positive Priviliged:1354
# True Negative Unpriviliged:27
# False Negative Unpriviliged:2622
# True Negative Priviliged:17
# False Negative Priviliged:1713
# Disparate impact: 3.3681461695007893
# Equal opportunity diff: 0.00214816576279849
# Statistical parity: 0.3093279210572085
# EO: 0.02678912237734103
# -----------------------------------
#   RESULTS for state: ME
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1562
#             1         965
# 1           0        1836
#             1         571
# dtype: int64
# Eğitim örnek sayısı: 4934
# Test örnek sayısı: 2068
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86      1481
#            1       0.66      0.60      0.63       587
#
#     accuracy                           0.80      2068
#    macro avg       0.76      0.74      0.75      2068
# weighted avg       0.80      0.80      0.80      2068
#
# Number of males: 1046
# Number of females: 1022
# True Positive Unpriviliged:0
# False Positive Unpriviliged:197
# True Positive Priviliged:0
# False Positive Priviliged:333
# True Negative Unpriviliged:2
# False Negative Unpriviliged:823
# True Negative Priviliged:5
# False Negative Priviliged:708
# Number of males: 1046
# Number of females: 1022
# True Positive Unpriviliged:0
# False Positive Unpriviliged:197
# True Positive Priviliged:0
# False Positive Priviliged:333
# True Negative Unpriviliged:2
# False Negative Unpriviliged:823
# True Negative Priviliged:5
# False Negative Priviliged:708
# Disparate impact: 1.651570886432239
# Equal opportunity diff: 0.0
# Statistical parity: 0.12559634503635134
# EO: 0.002371324076001269
# -----------------------------------
#   RESULTS for state: MD
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        5227
#             1        6431
# 1           0        6631
#             1        4849
# dtype: int64
# Eğitim örnek sayısı: 23138
# Test örnek sayısı: 9904
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79      5152
#            1       0.77      0.79      0.78      4752
#
#     accuracy                           0.79      9904
#    macro avg       0.79      0.79      0.79      9904
# weighted avg       0.79      0.79      0.79      9904
#
# Number of males: 4958
# Number of females: 4946
# True Positive Unpriviliged:17
# False Positive Unpriviliged:1961
# True Positive Priviliged:24
# False Positive Priviliged:2831
# True Negative Unpriviliged:36
# False Negative Unpriviliged:2932
# True Negative Priviliged:31
# False Negative Priviliged:2072
# Number of males: 4958
# Number of females: 4946
# True Positive Unpriviliged:17
# False Positive Unpriviliged:1961
# True Positive Priviliged:24
# False Positive Priviliged:2831
# True Negative Unpriviliged:36
# False Negative Unpriviliged:2932
# True Negative Priviliged:31
# False Negative Priviliged:2072
# Disparate impact: 1.4398836984971028
# Equal opportunity diff: 0.005685715690918645
# Statistical parity: 0.17591790449398892
# EO: 0.0064405849742377504
# -----------------------------------
#   RESULTS for state: MA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        6553
#             1        7595
# 1           0        8379
#             1        5440
# dtype: int64
# Eğitim örnek sayısı: 27967
# Test örnek sayısı: 12147
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80      6391
#            1       0.78      0.77      0.78      5756
#
#     accuracy                           0.79     12147
#    macro avg       0.79      0.79      0.79     12147
# weighted avg       0.79      0.79      0.79     12147
#
# Number of males: 6065
# Number of females: 6082
# True Positive Unpriviliged:25
# False Positive Unpriviliged:2149
# True Positive Priviliged:38
# False Positive Priviliged:3444
# True Negative Unpriviliged:51
# False Negative Unpriviliged:3857
# True Negative Priviliged:35
# False Negative Priviliged:2548
# Number of males: 6065
# Number of females: 6082
# True Positive Unpriviliged:25
# False Positive Unpriviliged:2149
# True Positive Priviliged:38
# False Positive Priviliged:3444
# True Negative Unpriviliged:51
# False Negative Unpriviliged:3857
# True Negative Priviliged:35
# False Negative Priviliged:2548
# Disparate impact: 1.606145323849041
# Equal opportunity diff: 0.008254529501978913
# Statistical parity: 0.21666555969217616
# EO: 0.01068799275537946
# -----------------------------------
#   RESULTS for state: MI
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        10638
#             1         7761
# 1           0        12504
#             1         4130
# dtype: int64
# Eğitim örnek sayısı: 35033
# Test örnek sayısı: 14975
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85     10005
#            1       0.72      0.66      0.69      4970
#
#     accuracy                           0.80     14975
#    macro avg       0.78      0.77      0.77     14975
# weighted avg       0.80      0.80      0.80     14975
#
# Number of males: 7857
# Number of females: 7118
# True Positive Unpriviliged:17
# False Positive Unpriviliged:1309
# True Positive Priviliged:41
# False Positive Priviliged:3220
# True Negative Unpriviliged:114
# False Negative Unpriviliged:5678
# True Negative Priviliged:80
# False Negative Priviliged:4516
# Number of males: 7857
# Number of females: 7118
# True Positive Unpriviliged:17
# False Positive Unpriviliged:1309
# True Positive Priviliged:41
# False Positive Priviliged:3220
# True Negative Unpriviliged:114
# False Negative Unpriviliged:5678
# True Negative Priviliged:80
# False Negative Priviliged:4516
# Disparate impact: 2.227965724428227
# Equal opportunity diff: 0.006012072619129501
# Statistical parity: 0.22875562666364552
# EO: 0.030941043443447502
# -----------------------------------
#   RESULTS for state: MN
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        6226
#             1        5222
# 1           0        7339
#             1        2895
# dtype: int64
# Eğitim örnek sayısı: 21682
# Test örnek sayısı: 9339
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      5906
#            1       0.72      0.67      0.69      3433
#
#     accuracy                           0.78      9339
#    macro avg       0.77      0.76      0.76      9339
# weighted avg       0.78      0.78      0.78      9339
#
# Number of males: 4965
# Number of females: 4374
# True Positive Unpriviliged:5
# False Positive Unpriviliged:898
# True Positive Priviliged:15
# False Positive Priviliged:2272
# True Negative Unpriviliged:34
# False Negative Unpriviliged:3437
# True Negative Priviliged:43
# False Negative Priviliged:2635
# Number of males: 4965
# Number of females: 4374
# True Positive Unpriviliged:5
# False Positive Unpriviliged:898
# True Positive Priviliged:15
# False Positive Priviliged:2272
# True Negative Unpriviliged:34
# False Negative Unpriviliged:3437
# True Negative Priviliged:43
# False Negative Priviliged:2635
# Disparate impact: 2.23119711736307
# Equal opportunity diff: 0.0042077335467532034
# Statistical parity: 0.2541771826654897
# EO: 0.011056953101577623
# -----------------------------------
#   RESULTS for state: MS
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        2938
#             1        1664
# 1           0        3706
#             1         832
# dtype: int64
# Eğitim örnek sayısı: 9140
# Test örnek sayısı: 4049
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88      2990
#            1       0.68      0.52      0.59      1059
#
#     accuracy                           0.81      4049
#    macro avg       0.76      0.72      0.73      4049
# weighted avg       0.80      0.81      0.80      4049
#
# Number of males: 2052
# Number of females: 1997
# True Positive Unpriviliged:1
# False Positive Unpriviliged:171
# True Positive Priviliged:1
# False Positive Priviliged:645
# True Negative Unpriviliged:8
# False Negative Unpriviliged:1817
# True Negative Priviliged:6
# False Negative Priviliged:1400
# Number of males: 2052
# Number of females: 1997
# True Positive Unpriviliged:1
# False Positive Unpriviliged:171
# True Positive Priviliged:1
# False Positive Priviliged:645
# True Negative Unpriviliged:8
# False Negative Unpriviliged:1817
# True Negative Priviliged:6
# False Negative Priviliged:1400
# Disparate impact: 3.6551464254952633
# Equal opportunity diff: 0.0001637208688748961
# Statistical parity: 0.22868562102412882
# EO: 0.017819934218645667
# -----------------------------------
#   RESULTS for state: MO
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        7086
#             1        4412
# 1           0        8277
#             1        2438
# dtype: int64
# Eğitim örnek sayısı: 22213
# Test örnek sayısı: 9451
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      6544
#            1       0.71      0.57      0.63      2907
#
#     accuracy                           0.80      9451
#    macro avg       0.77      0.73      0.75      9451
# weighted avg       0.79      0.80      0.79      9451
#
# Number of males: 4890
# Number of females: 4561
# True Positive Unpriviliged:4
# False Positive Unpriviliged:683
# True Positive Priviliged:10
# False Positive Priviliged:1662
# True Negative Unpriviliged:64
# False Negative Unpriviliged:3810
# True Negative Priviliged:46
# False Negative Priviliged:3172
# Number of males: 4890
# Number of females: 4561
# True Positive Unpriviliged:4
# False Positive Unpriviliged:683
# True Positive Priviliged:10
# False Positive Priviliged:1662
# True Negative Unpriviliged:64
# False Negative Unpriviliged:3810
# True Negative Priviliged:46
# False Negative Priviliged:3172
# Disparate impact: 2.2700255698139267
# Equal opportunity diff: 0.0020939098633273095
# Statistical parity: 0.19129742741990083
# EO: 0.030418931518730073
# -----------------------------------
#   RESULTS for state: MT
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1255
#             1         745
# 1           0        1362
#             1         363
# dtype: int64
# Eğitim örnek sayısı: 3725
# Test örnek sayısı: 1738
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1248
#            1       0.66      0.55      0.60       490
#
#     accuracy                           0.79      1738
#    macro avg       0.75      0.72      0.73      1738
# weighted avg       0.79      0.79      0.79      1738
#
# Number of males: 943
# Number of females: 795
# True Positive Unpriviliged:0
# False Positive Unpriviliged:77
# True Positive Priviliged:0
# False Positive Priviliged:334
# True Negative Unpriviliged:1
# False Negative Unpriviliged:717
# True Negative Priviliged:1
# False Negative Priviliged:608
# Number of males: 943
# Number of females: 795
# True Positive Unpriviliged:0
# False Positive Unpriviliged:77
# True Positive Priviliged:0
# False Positive Priviliged:334
# True Negative Unpriviliged:1
# False Negative Unpriviliged:717
# True Negative Priviliged:1
# False Negative Priviliged:608
# Disparate impact: 3.6568839432041975
# Equal opportunity diff: 0.0
# Statistical parity: 0.2573334133669475
# EO: 0.004917719096823536
# -----------------------------------
#   RESULTS for state: NE
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        2434
#             1        1521
# 1           0        2750
#             1         817
# dtype: int64
# Eğitim örnek sayısı: 7522
# Test örnek sayısı: 3263
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      2233
#            1       0.70      0.55      0.62      1030
#
#     accuracy                           0.78      3263
#    macro avg       0.76      0.72      0.73      3263
# weighted avg       0.78      0.78      0.78      3263
#
# Number of males: 1736
# Number of females: 1527
# True Positive Unpriviliged:0
# False Positive Unpriviliged:191
# True Positive Priviliged:4
# False Positive Priviliged:622
# True Negative Unpriviliged:2
# False Negative Unpriviliged:1334
# True Negative Priviliged:6
# False Negative Priviliged:1104
# Number of males: 1736
# Number of females: 1527
# True Positive Unpriviliged:0
# False Positive Unpriviliged:191
# True Positive Priviliged:4
# False Positive Priviliged:622
# True Negative Unpriviliged:2
# False Negative Unpriviliged:1334
# True Negative Priviliged:6
# False Negative Priviliged:1104
# Disparate impact: 2.882904673438367
# Equal opportunity diff: 0.0036101083032490976
# Statistical parity: 0.2355172184850872
# EO: 0.002209331238189368
# -----------------------------------
#   RESULTS for state: NV
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        3294
#             1        2149
# 1           0        3571
#             1        1335
# dtype: int64
# Eğitim örnek sayısı: 10349
# Test örnek sayısı: 4458
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      2957
#            1       0.71      0.63      0.67      1501
#
#     accuracy                           0.79      4458
#    macro avg       0.77      0.75      0.76      4458
# weighted avg       0.79      0.79      0.79      4458
#
# Number of males: 2365
# Number of females: 2093
# True Positive Unpriviliged:2
# False Positive Unpriviliged:408
# True Positive Priviliged:4
# False Positive Priviliged:927
# True Negative Unpriviliged:13
# False Negative Unpriviliged:1670
# True Negative Priviliged:4
# False Negative Priviliged:1430
# Number of males: 2365
# Number of females: 2093
# True Positive Unpriviliged:2
# False Positive Unpriviliged:408
# True Positive Priviliged:4
# False Positive Priviliged:927
# True Negative Unpriviliged:13
# False Negative Unpriviliged:1670
# True Negative Priviliged:4
# False Negative Priviliged:1430
# Disparate impact: 2.00957355746919
# Equal opportunity diff: 0.0015932280301362
# Statistical parity: 0.19776643982912942
# EO: 0.014087816231671726
# -----------------------------------
#   RESULTS for state: NH
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1465
#             1        1414
# 1           0        1915
#             1         790
# dtype: int64
# Eğitim örnek sayısı: 5584
# Test örnek sayısı: 2382
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82      1400
#            1       0.77      0.70      0.73       982
#
#     accuracy                           0.79      2382
#    macro avg       0.78      0.77      0.78      2382
# weighted avg       0.79      0.79      0.79      2382
#
# Number of males: 1246
# Number of females: 1136
# True Positive Unpriviliged:1
# False Positive Unpriviliged:234
# True Positive Priviliged:1
# False Positive Priviliged:660
# True Negative Unpriviliged:4
# False Negative Unpriviliged:897
# True Negative Priviliged:4
# False Negative Priviliged:581
# Number of males: 1246
# Number of females: 1136
# True Positive Unpriviliged:1
# False Positive Unpriviliged:234
# True Positive Priviliged:1
# False Positive Priviliged:660
# True Negative Unpriviliged:4
# False Negative Unpriviliged:897
# True Negative Priviliged:4
# False Negative Priviliged:581
# Disparate impact: 2.564447935521328
# Equal opportunity diff: 0.0006046273123167941
# Statistical parity: 0.3236313951122465
# EO: 0.0056936268079251715
# -----------------------------------
#   RESULTS for state: NJ
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        7692
#             1        9644
# 1           0        9343
#             1        6644
# dtype: int64
# Eğitim örnek sayısı: 33323
# Test örnek sayısı: 14458
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79      7316
#            1       0.78      0.80      0.79      7142
#
#     accuracy                           0.79     14458
#    macro avg       0.79      0.79      0.79     14458
# weighted avg       0.79      0.79      0.79     14458
#
# Number of males: 7493
# Number of females: 6965
# True Positive Unpriviliged:31
# False Positive Unpriviliged:2741
# True Positive Priviliged:68
# False Positive Priviliged:4522
# True Negative Unpriviliged:48
# False Negative Unpriviliged:4145
# True Negative Priviliged:47
# False Negative Priviliged:2856
# Number of males: 7493
# Number of females: 6965
# True Positive Unpriviliged:31
# False Positive Unpriviliged:2741
# True Positive Priviliged:68
# False Positive Priviliged:4522
# True Negative Unpriviliged:48
# False Negative Unpriviliged:4145
# True Negative Priviliged:47
# False Negative Priviliged:2856
# Disparate impact: 1.539163825631195
# Equal opportunity diff: 0.015832442305978793
# Statistical parity: 0.21458178386929977
# EO: 0.011378098595567206
# -----------------------------------
#   RESULTS for state: NM
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        2053
#             1        1105
# 1           0        2240
#             1         714
# dtype: int64
# Eğitim örnek sayısı: 6112
# Test örnek sayısı: 2599
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1825
#            1       0.69      0.55      0.61       774
#
#     accuracy                           0.79      2599
#    macro avg       0.76      0.72      0.74      2599
# weighted avg       0.79      0.79      0.79      2599
#
# Number of males: 1354
# Number of females: 1245
# True Positive Unpriviliged:1
# False Positive Unpriviliged:207
# True Positive Priviliged:1
# False Positive Priviliged:411
# True Negative Unpriviliged:3
# False Negative Unpriviliged:1034
# True Negative Priviliged:3
# False Negative Priviliged:939
# Number of males: 1354
# Number of females: 1245
# True Positive Unpriviliged:1
# False Positive Unpriviliged:207
# True Positive Priviliged:1
# False Positive Priviliged:411
# True Negative Unpriviliged:3
# False Negative Unpriviliged:1034
# True Negative Priviliged:3
# False Negative Priviliged:939
# Disparate impact: 1.8213129189864787
# Equal opportunity diff: 9.764621235481554e-05
# Statistical parity: 0.13721533104352418
# EO: 0.003568491843237408
# -----------------------------------
#   RESULTS for state: NY
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        19341
#             1        17127
# 1           0        22915
#             1        12770
# dtype: int64
# Eğitim örnek sayısı: 72153
# Test örnek sayısı: 30868
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81     18038
#            1       0.74      0.70      0.72     12830
#
#     accuracy                           0.77     30868
#    macro avg       0.77      0.76      0.76     30868
# weighted avg       0.77      0.77      0.77     30868
#
# Number of males: 15710
# Number of females: 15158
# True Positive Unpriviliged:106
# False Positive Unpriviliged:4394
# True Positive Priviliged:175
# False Positive Priviliged:7429
# True Negative Unpriviliged:406
# False Negative Unpriviliged:10252
# True Negative Priviliged:301
# False Negative Priviliged:7805
# Number of males: 15710
# Number of females: 15158
# True Positive Unpriviliged:106
# False Positive Unpriviliged:4394
# True Positive Priviliged:175
# False Positive Priviliged:7429
# True Negative Unpriviliged:406
# False Negative Unpriviliged:10252
# True Negative Priviliged:301
# False Negative Priviliged:7805
# Disparate impact: 1.6304043001626707
# Equal opportunity diff: 0.011696188724369332
# Statistical parity: 0.1871499769581751
# EO: 0.02867016206378017
# -----------------------------------
#   RESULTS for state: NC
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        11336
#             1         7497
# 1           0        13381
#             1         4350
# dtype: int64
# Eğitim örnek sayısı: 36564
# Test örnek sayısı: 15503
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85     10370
#            1       0.72      0.60      0.66      5133
#
#     accuracy                           0.79     15503
#    macro avg       0.77      0.74      0.75     15503
# weighted avg       0.79      0.79      0.79     15503
#
# Number of males: 7914
# Number of females: 7589
# True Positive Unpriviliged:11
# False Positive Unpriviliged:1251
# True Positive Priviliged:34
# False Positive Priviliged:2957
# True Negative Unpriviliged:129
# False Negative Unpriviliged:6198
# True Negative Priviliged:96
# False Negative Priviliged:4827
# Number of males: 7914
# Number of females: 7589
# True Positive Unpriviliged:11
# False Positive Unpriviliged:1251
# True Positive Priviliged:34
# False Positive Priviliged:2957
# True Negative Unpriviliged:129
# False Negative Unpriviliged:6198
# True Negative Priviliged:96
# False Negative Priviliged:4827
# Disparate impact: 2.272718070285682
# Equal opportunity diff: 0.005222823748062128
# Statistical parity: 0.21164451241277252
# EO: 0.033628301889553944
# -----------------------------------
#   RESULTS for state: ND
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0         902
#             1         826
# 1           0        1077
#             1         324
# dtype: int64
# Eğitim örnek sayısı: 3129
# Test örnek sayısı: 1326
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82       840
#            1       0.70      0.59      0.64       486
#
#     accuracy                           0.76      1326
#    macro avg       0.74      0.72      0.73      1326
# weighted avg       0.75      0.76      0.75      1326
#
# Number of males: 742
# Number of females: 584
# True Positive Unpriviliged:0
# False Positive Unpriviliged:57
# True Positive Priviliged:1
# False Positive Priviliged:356
# True Negative Unpriviliged:0
# False Negative Unpriviliged:527
# True Negative Priviliged:0
# False Negative Priviliged:385
# Number of males: 742
# Number of females: 584
# True Positive Unpriviliged:0
# False Positive Unpriviliged:57
# True Positive Priviliged:1
# False Positive Priviliged:356
# True Negative Unpriviliged:0
# False Negative Unpriviliged:527
# True Negative Priviliged:0
# False Negative Priviliged:385
# Disparate impact: 4.929493545183714
# Equal opportunity diff: 0.0025906735751295338
# Statistical parity: 0.3835293357456707
# EO: 0.0012953367875647669
# -----------------------------------
#   RESULTS for state: OH
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        12973
#             1         9465
# 1           0        15660
#             1         5334
# dtype: int64
# Eğitim örnek sayısı: 43432
# Test örnek sayısı: 18703
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85     12396
#            1       0.72      0.64      0.68      6307
#
#     accuracy                           0.80     18703
#    macro avg       0.77      0.76      0.76     18703
# weighted avg       0.79      0.80      0.79     18703
#
# Number of males: 9781
# Number of females: 8922
# True Positive Unpriviliged:15
# False Positive Unpriviliged:1461
# True Positive Priviliged:46
# False Positive Priviliged:4052
# True Negative Unpriviliged:179
# False Negative Unpriviliged:7267
# True Negative Priviliged:135
# False Negative Priviliged:5548
# Number of males: 9781
# Number of females: 8922
# True Positive Unpriviliged:15
# False Positive Unpriviliged:1461
# True Positive Priviliged:46
# False Positive Priviliged:4052
# True Negative Unpriviliged:179
# False Negative Unpriviliged:7267
# True Negative Priviliged:135
# False Negative Priviliged:5548
# Disparate impact: 2.532588068953995
# Equal opportunity diff: 0.006163222513390529
# Statistical parity: 0.25354180562386197
# EO: 0.04153345406865095
# -----------------------------------
#   RESULTS for state: OK
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        4139
#             1        2488
# 1           0        4836
#             1        1072
# dtype: int64
# Eğitim örnek sayısı: 12535
# Test örnek sayısı: 5382
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      3883
#            1       0.68      0.55      0.61      1499
#
#     accuracy                           0.80      5382
#    macro avg       0.76      0.73      0.74      5382
# ...
#             1        3369
# 1           0        6577
#             1        1986
# dtype: int64
# Eğitim örnek sayısı: 17320
# Test örnek sayısı: 7559
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      5274
#            1       0.70      0.59      0.64      2285
#
#     accuracy                           0.80      7559
#    macro avg       0.77      0.74      0.75      7559
# weighted avg       0.79      0.80      0.79      7559
#
# Number of males: 3857
# Number of females: 3702
# True Positive Unpriviliged:3
# False Positive Unpriviliged:558
# True Positive Priviliged:3
# False Positive Priviliged:1368
# True Negative Unpriviliged:40
# False Negative Unpriviliged:3101
# True Negative Priviliged:19
# False Negative Priviliged:2467
# Number of males: 3857
# Number of females: 3702
# True Positive Unpriviliged:3
# False Positive Unpriviliged:558
# True Positive Priviliged:3
# False Positive Priviliged:1368
# True Negative Unpriviliged:40
# False Negative Unpriviliged:3101
# True Negative Priviliged:19
# False Negative Priviliged:2467
# Disparate impact: 2.3456400544048672
# Equal opportunity diff: 0.0002480800534246004
# Statistical parity: 0.20391790127529186
# EO: 0.026719541011730807
# -----------------------------------
#   RESULTS for state: SD
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1126
#             1         662
# 1           0        1359
#             1         291
# dtype: int64
# Eğitim örnek sayısı: 3438
# Test örnek sayısı: 1461
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87      1091
#            1       0.62      0.47      0.53       370
#
#     accuracy                           0.79      1461
#    macro avg       0.73      0.68      0.70      1461
# weighted avg       0.78      0.79      0.78      1461
#
# Number of males: 751
# Number of females: 710
# True Positive Unpriviliged:0
# False Positive Unpriviliged:36
# True Positive Priviliged:1
# False Positive Priviliged:243
# True Negative Unpriviliged:0
# False Negative Unpriviliged:674
# True Negative Priviliged:1
# False Negative Priviliged:506
# Number of males: 751
# Number of females: 710
# True Positive Unpriviliged:0
# False Positive Unpriviliged:36
# True Positive Priviliged:1
# False Positive Priviliged:243
# True Negative Unpriviliged:0
# False Negative Unpriviliged:674
# True Negative Priviliged:1
# False Negative Priviliged:506
# Disparate impact: 6.407752626128126
# Equal opportunity diff: 0.0019723865877712033
# Statistical parity: 0.27419590780367964
# EO: 0.0030353736217544284
# -----------------------------------
#   RESULTS for state: TN
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        7543
#             1        4789
# 1           0        8865
#             1        2584
# dtype: int64
# Eğitim örnek sayısı: 23781
# Test örnek sayısı: 10222
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      7140
#            1       0.69      0.57      0.63      3082
#
#     accuracy                           0.79     10222
#    macro avg       0.76      0.73      0.74     10222
# weighted avg       0.79      0.79      0.79     10222
#
# Number of males: 5300
# Number of females: 4922
# True Positive Unpriviliged:4
# False Positive Unpriviliged:645
# True Positive Priviliged:9
# False Positive Priviliged:1881
# True Negative Unpriviliged:57
# False Negative Unpriviliged:4216
# True Negative Priviliged:49
# False Negative Priviliged:3361
# Number of males: 5300
# Number of females: 4922
# True Positive Unpriviliged:4
# False Positive Unpriviliged:645
# True Positive Priviliged:9
# False Positive Priviliged:1881
# True Negative Unpriviliged:57
# False Negative Unpriviliged:4216
# True Negative Priviliged:49
# False Negative Priviliged:3361
# Disparate impact: 2.7044742274035527
# Equal opportunity diff: 0.0017227558468223944
# Statistical parity: 0.22474680487299992
# EO: 0.028765368003567125
# -----------------------------------
#   RESULTS for state: TX
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        28423
#             1        22097
# 1           0        31933
#             1        12533
# dtype: int64
# Eğitim örnek sayısı: 94986
# Test örnek sayısı: 40938
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84     25983
#            1       0.73      0.67      0.70     14955
#
#     accuracy                           0.79     40938
#    macro avg       0.77      0.76      0.77     40938
# weighted avg       0.78      0.79      0.79     40938
#
# Number of males: 21709
# Number of females: 19229
# True Positive Unpriviliged:123
# False Positive Unpriviliged:3943
# True Positive Priviliged:263
# False Positive Priviliged:9322
# True Negative Unpriviliged:763
# False Negative Unpriviliged:14400
# True Negative Priviliged:608
# False Negative Priviliged:11516
# Number of males: 21709
# Number of females: 19229
# True Positive Unpriviliged:123
# False Positive Unpriviliged:3943
# True Positive Priviliged:263
# False Positive Priviliged:9322
# True Negative Unpriviliged:763
# False Negative Unpriviliged:14400
# True Negative Priviliged:608
# False Negative Priviliged:11516
# Disparate impact: 2.0880535084686893
# Equal opportunity diff: 0.013858547116234977
# Statistical parity: 0.23007049588817366
# EO: 0.057381696789329285
# -----------------------------------
#   RESULTS for state: UT
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        3340
#             1        2852
# 1           0        4367
#             1         951
# dtype: int64
# Eğitim örnek sayısı: 11510
# Test örnek sayısı: 4827
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      3176
#            1       0.76      0.67      0.71      1651
#
#     accuracy                           0.81      4827
#    macro avg       0.80      0.78      0.79      4827
# weighted avg       0.81      0.81      0.81      4827
#
# Number of males: 2624
# Number of females: 2203
# True Positive Unpriviliged:0
# False Positive Unpriviliged:219
# True Positive Priviliged:4
# False Positive Priviliged:1243
# True Negative Unpriviliged:9
# False Negative Unpriviliged:1975
# True Negative Priviliged:9
# False Negative Priviliged:1368
# Number of males: 2624
# Number of females: 2203
# True Positive Unpriviliged:0
# False Positive Unpriviliged:219
# True Positive Priviliged:4
# False Positive Priviliged:1243
# True Negative Unpriviliged:9
# False Negative Unpriviliged:1975
# True Negative Priviliged:9
# False Negative Priviliged:1368
# Disparate impact: 4.780496505735606
# Equal opportunity diff: 0.0029154518950437317
# Statistical parity: 0.3758187629396721
# EO: 0.017600318851507098
# -----------------------------------
#   RESULTS for state: VT
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        800
#             1        535
# 1           0        889
#             1        388
# dtype: int64
# Eğitim örnek sayısı: 2612
# Test örnek sayısı: 1155
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       785
#            1       0.64      0.61      0.62       370
#
#     accuracy                           0.77      1155
#    macro avg       0.73      0.72      0.73      1155
# weighted avg       0.76      0.77      0.76      1155
#
# Number of males: 594
# Number of females: 561
# True Positive Unpriviliged:0
# False Positive Unpriviliged:122
# True Positive Priviliged:0
# False Positive Priviliged:228
# True Negative Unpriviliged:0
# False Negative Unpriviliged:439
# True Negative Priviliged:2
# False Negative Priviliged:364
# Number of males: 594
# Number of females: 561
# True Positive Unpriviliged:0
# False Positive Unpriviliged:122
# True Positive Priviliged:0
# False Positive Priviliged:228
# True Negative Unpriviliged:0
# False Negative Unpriviliged:439
# True Negative Priviliged:2
# False Negative Priviliged:364
# Disparate impact: 1.7650273224043715
# Equal opportunity diff: 0.0
# Statistical parity: 0.166369578134284
# EO: 0.004347826086956497
# -----------------------------------
#   RESULTS for state: VA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0         8131
#             1         8595
# 1           0        10103
#             1         5492
# dtype: int64
# Eğitim örnek sayısı: 32321
# Test örnek sayısı: 13823
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      7743
#            1       0.77      0.75      0.76      6080
#
#     accuracy                           0.79     13823
#    macro avg       0.79      0.79      0.79     13823
# weighted avg       0.79      0.79      0.79     13823
#
# Number of males: 7108
# Number of females: 6715
# True Positive Unpriviliged:28
# False Positive Unpriviliged:2060
# True Positive Priviliged:36
# False Positive Priviliged:3773
# True Negative Unpriviliged:80
# False Negative Unpriviliged:4547
# True Negative Priviliged:50
# False Negative Priviliged:3249
# Number of males: 7108
# Number of females: 6715
# True Positive Unpriviliged:28
# False Positive Unpriviliged:2060
# True Positive Priviliged:36
# False Positive Priviliged:3773
# True Negative Unpriviliged:80
# False Negative Unpriviliged:4547
# True Negative Priviliged:50
# False Negative Priviliged:3249
# Disparate impact: 1.723372173062784
# Equal opportunity diff: 0.0048386855303540685
# Statistical parity: 0.22492942626285822
# EO: 0.014571564560948335
# -----------------------------------
#   RESULTS for state: WA
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        7342
#             1        7519
# 1           0        8660
#             1        4410
# dtype: int64
# Eğitim örnek sayısı: 27931
# Test örnek sayısı: 12013
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80      6832
#            1       0.74      0.73      0.74      5181
#
#     accuracy                           0.78     12013
#    macro avg       0.77      0.77      0.77     12013
# weighted avg       0.78      0.78      0.78     12013
#
# Number of males: 6352
# Number of females: 5661
# True Positive Unpriviliged:15
# False Positive Unpriviliged:1545
# True Positive Priviliged:41
# False Positive Priviliged:3521
# True Negative Unpriviliged:50
# False Negative Unpriviliged:4051
# True Negative Priviliged:44
# False Negative Priviliged:2746
# Number of males: 6352
# Number of females: 5661
# True Positive Unpriviliged:15
# False Positive Unpriviliged:1545
# True Positive Priviliged:41
# False Positive Priviliged:3521
# True Negative Unpriviliged:50
# False Negative Unpriviliged:4051
# True Negative Priviliged:44
# False Negative Priviliged:2746
# Disparate impact: 2.0349417506297227
# Equal opportunity diff: 0.011022029586808686
# Statistical parity: 0.28519857463034226
# EO: 0.015013887990237028
# -----------------------------------
#   RESULTS for state: WV
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        1874
#             1        1116
# 1           0        2173
#             1         552
# dtype: int64
# Eğitim örnek sayısı: 5715
# Test örnek sayısı: 2388
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1701
#            1       0.67      0.57      0.62       687
#
#     accuracy                           0.80      2388
#    macro avg       0.76      0.73      0.74      2388
# weighted avg       0.79      0.80      0.79      2388
#
# Number of males: 1295
# Number of females: 1093
# True Positive Unpriviliged:0
# False Positive Unpriviliged:120
# True Positive Priviliged:0
# False Positive Priviliged:463
# True Negative Unpriviliged:2
# False Negative Unpriviliged:971
# True Negative Priviliged:2
# False Negative Priviliged:830
# Number of males: 1295
# Number of females: 1093
# True Positive Unpriviliged:0
# False Positive Unpriviliged:120
# True Positive Priviliged:0
# False Positive Priviliged:463
# True Negative Unpriviliged:2
# False Negative Unpriviliged:971
# True Negative Priviliged:2
# False Negative Priviliged:830
# Disparate impact: 3.2564929214929217
# Equal opportunity diff: 0.0
# Statistical parity: 0.24773938753810665
# EO: 0.00604618367706683
# -----------------------------------
#   RESULTS for state: WI
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        6930
#             1        5122
# 1           0        8181
#             1        2691
# dtype: int64
# Eğitim örnek sayısı: 22924
# Test örnek sayısı: 9766
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      6422
#            1       0.71      0.64      0.67      3344
#
#     accuracy                           0.79      9766
#    macro avg       0.76      0.75      0.76      9766
# weighted avg       0.78      0.79      0.78      9766
#
# Number of males: 5144
# Number of females: 4622
# True Positive Unpriviliged:5
# False Positive Unpriviliged:870
# True Positive Priviliged:18
# False Positive Priviliged:2106
# True Negative Unpriviliged:39
# False Negative Unpriviliged:3708
# True Negative Priviliged:40
# False Negative Priviliged:2980
# Number of males: 5144
# Number of females: 4622
# True Positive Unpriviliged:5
# False Positive Unpriviliged:870
# True Positive Priviliged:18
# False Positive Priviliged:2106
# True Negative Unpriviliged:39
# False Negative Unpriviliged:3708
# True Negative Priviliged:40
# False Negative Priviliged:2980
# Disparate impact: 2.1810993112641635
# Equal opportunity diff: 0.00465738268460507
# Statistical parity: 0.2235962564595723
# EO: 0.014461172064745696
# -----------------------------------
#   RESULTS for state: WY
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        601
#             1        531
# 1           0        782
#             1        229
# dtype: int64
# Eğitim örnek sayısı: 2143
# Test örnek sayısı: 921
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       585
#            1       0.69      0.59      0.63       336
#
#     accuracy                           0.75       921
#    macro avg       0.73      0.72      0.72       921
# weighted avg       0.75      0.75      0.75       921
#
# Number of males: 497
# Number of females: 424
# True Positive Unpriviliged:0
# False Positive Unpriviliged:55
# True Positive Priviliged:0
# False Positive Priviliged:234
# True Negative Unpriviliged:0
# False Negative Unpriviliged:369
# True Negative Priviliged:0
# False Negative Priviliged:263
# Number of males: 497
# Number of females: 424
# True Positive Unpriviliged:0
# False Positive Unpriviliged:55
# True Positive Priviliged:0
# False Positive Priviliged:234
# True Negative Unpriviliged:0
# False Negative Unpriviliged:369
# True Negative Priviliged:0
# False Negative Priviliged:263
# Disparate impact: 3.6296323394914944
# Equal opportunity diff: 0.0
# Statistical parity: 0.34110796856611364
# EO: 0.0
# -----------------------------------
#   RESULTS for state: PR
# -----------------------------------
# Cinsiyet Dağılımı Train:
# SEX_Female  PINCP
# 0           0        2955
#             1         442
# 1           0        2659
#             1         234
# dtype: int64
# Eğitim örnek sayısı: 6290
# Test örnek sayısı: 2781
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      2495
#            1       0.59      0.28      0.38       286
#
#     accuracy                           0.91      2781
#    macro avg       0.76      0.63      0.66      2781
# weighted avg       0.89      0.91      0.89      2781
#
# Number of males: 1451
# Number of females: 1330
# True Positive Unpriviliged:0
# False Positive Unpriviliged:38
# True Positive Priviliged:0
# False Positive Priviliged:95
# True Negative Unpriviliged:8
# False Negative Unpriviliged:1284
# True Negative Priviliged:6
# False Negative Priviliged:1350
# Number of males: 1451
# Number of females: 1330
# True Positive Unpriviliged:0
# False Positive Unpriviliged:38
# True Positive Priviliged:0
# False Positive Priviliged:95
# True Negative Unpriviliged:8
# False Negative Unpriviliged:1284
# True Negative Priviliged:6
# False Negative Priviliged:1350
# Disparate impact: 2.291523087525844
# Equal opportunity diff: 0.0
# Statistical parity: 0.036900659643595554
# EO: 0.0572535514421007
