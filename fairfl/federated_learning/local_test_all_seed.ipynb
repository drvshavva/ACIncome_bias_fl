# %%
import copy

import pandas as pd
import pickle

from fairfl.model.preprocess import ACSIncomePreprocess
from fairfl.model.model import ACSIncomeModel
from fairfl.metrics.bias_metrics import BiasType

# %%
bias_type = BiasType.race
model_n = "fairfl_nirm_2"
preprocess = ACSIncomePreprocess()
model = ACSIncomeModel(bias_type=bias_type)

# %%
from fairfl.utils.read_data import DatasetUtils

# %%
states = ["MT", "WY", "ID", "VT", "UT", "SD", "ME", "NH", "OR", "ND", "IA", "AK", "HI", "NM", "NE", "CO", "WI", "MN",
          "WA", "WV"]

# %%
test = pd.read_csv("../../dataset/test_preprocessed_label.csv").reset_index(drop=True)

# %%
def get_df_for_seed(model_name, seed, df):
    df_c = copy.deepcopy(df)
    states_result_dfs = list()
    lr_model = pickle.load(open(f"res_v2/{model_name}_seed{seed}.pkl", "rb"))
    for state in states:
        res = model.print_loaded_model_metrics(df_c, lr_model, state)
        states_result_dfs.append(res)
    pd.concat(states_result_dfs).to_excel(f"{model_name}/{model_name}_seed{seed}.xlsx", index=False)
    return states_result_dfs

# %%
for i in range(1, 11):
    get_df_for_seed(model_n, i, test)
# Out:
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /home/safir/.virtualenvs/ACIncome_bias_fl/lib/python3.8/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
